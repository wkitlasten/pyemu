# %% [markdown]
# # A verbose walk thru of gaussian-process-regression emulation for global optimization
#
# In this notebook, we go thru much pain to demonstrate how GPR can be used for so-called "bayesian optimization" (BO) with a very naive in-filling strategy.  Many of the steps and operations in this notebook are done only for the purposes of hoping to explain how GPR emulation works in the context of global evolutionary optimization.
#
# We will be using the well-known hosaki function for this analysis

# %%
import os
import sys
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyemu
# Out:
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# First we need to prepare for the GPR experiments.  Let's get the original model directory and copy it

# %%
org_d = os.path.join("..","autotest","utils","hosaki_template")
assert os.path.exists(org_d)

# %%
t_d = "hosaki_template"
if os.path.exists(t_d):
    shutil.rmtree(t_d)
shutil.copytree(org_d,t_d)

## uncomment this if you don't have pestpp exes in your path! or you can copy in whatever version exes you'd like into t_d
# pyemu.utils.get_pestpp(t_d)
# Out:
# Fetched release '5.2.16' info from 'usgs/pestpp'.
# using previous download '/Users/kmarkovich/Downloads/pestpp-5.2.16-mac.tar.gz' (use 'force=True' to re-download)
#
# A *.tar.gz file ('/Users/kmarkovich/Downloads/pestpp-5.2.16-mac.tar.gz') has been downloaded  and will be converted to a zip file ('/Users/kmarkovich/Downloads/pestpp-5.2.16-mac.zip').
#
# Extracting 8 files to '/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template'
# pestpp-da  pestpp-ies pestpp-opt pestpp-sqp
# pestpp-glm pestpp-mou pestpp-sen pestpp-swp
#
# Updated pyemu metadata file: '/Users/kmarkovich/.local/share/pyemu/get_pestpp.json'

# %%
pst = pyemu.Pst(os.path.join(t_d,"pest.pst"))

# %%
par = pst.parameter_data
par
# Out:
#        parnme partrans parchglim  parval1  parlbnd  parubnd  pargp  scale  \
# parnme
# par1     par1     none  relative      2.5      0.0      5.0  pargp    1.0
# par2     par2     none  relative      2.5      0.0      5.0  pargp    1.0
#
#         offset dercom  extra
# parnme
# par1       0.0      1    NaN
# par2       0.0      1    NaN

# %% [markdown]
# The hosaki function only has two decision variables - its very simple.  But in general, GPR-based emulation does not scale to extreme dimensions (like those seem in ensemble-based DA), but well within the space of global (multi-objective) optimization, so its an obvious pairing with pestpp-mou...
#
# The hosaki function only has 1 objective and no constraints and our goal is to minimize this single objective:

# %%
pst.observation_data
# Out:
#        obsnme    obsval  weight     obgnme  extra
# obsnme
# sim       sim -2.345812   100.0  less_than    NaN

# %% [markdown]
# First, lets sweep over decision variable space so that we can map the "true" objective function surface. You would never do this in practice but it helps us understand the GPR emulation process:

# %%
pvals = []
sweep_steps = 30
for p1 in np.linspace(par.parlbnd.iloc[0],par.parubnd.iloc[0],sweep_steps):
    for p2 in np.linspace(par.parlbnd.iloc[0],par.parubnd.iloc[0],sweep_steps):
        pvals.append([p1,p2])
pvals = pd.DataFrame(pvals,columns=pst.par_names)
pvals.to_csv(os.path.join(t_d,"sweep_in.csv"))
pst.pestpp_options["ies_par_en"] = "sweep_in.csv"
pst.control_data.noptmax = -1
sweep_d = os.path.join("hosaki_sweep")
pst.pestpp_options["ies_include_base"] = False

pst.write(os.path.join(t_d,"pest.pst"))
port = 5544
num_workers = 10
sys.path.insert(0,t_d)
from forward_run import hosaki_ppw_worker as ppw_function
pyemu.os_utils.start_workers(t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=sweep_d,worker_root='.',
                             port=port,ppw_function=ppw_function)
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:27:02
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:27:02
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:27:27 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.422 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual          28874        18159.8       0.213193        83320.2
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.89e+04  1.82e+04     0.213  8.33e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual          28874        18159.8       0.213193        83320.2
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.89e+04  1.82e+04     0.213  8.33e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:27:02
# finished at 06/06/25 08:27:28
# took 0.416667 minutes
# 2025-06-06 08:27:03.503196 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.755501 : connected to localhost:5544
# 2025-06-06 08:27:03.487556 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.742866 : connected to localhost:5544
# 2025-06-06 08:27:03.492395 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.747843 : connected to localhost:5544
# 2025-06-06 08:27:03.499457 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.755514 : connected to localhost:5544
# 2025-06-06 08:27:03.479065 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.738935 : connected to localhost:5544
# 2025-06-06 08:27:03.499334 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.755508 : connected to localhost:5544
# 2025-06-06 08:27:03.477713 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.733366 : connected to localhost:5544
# 2025-06-06 08:27:03.513222 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.768990 : connected to localhost:5544
# 2025-06-06 08:27:03.509529 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.764899 : connected to localhost:5544
# 2025-06-06 08:27:03.508494 : trying to connect to localhost:5544...
# 2025-06-06 08:27:03.762306 : connected to localhost:5544

# %% [markdown]
# And lets load up the sweep results so we can plot:

# %%
sweep_pe = pd.read_csv(os.path.join(sweep_d,"pest.0.par.csv"),index_col=0)
sweep_oe = pd.read_csv(os.path.join(sweep_d,"pest.0.obs.csv"),index_col=0)
sweep_x = sweep_pe.loc[:,pst.par_names[0]].values.reshape(sweep_steps,sweep_steps)
sweep_y = sweep_pe.loc[:,pst.par_names[1]].values.reshape(sweep_steps,sweep_steps)
sweep_z = sweep_oe.loc[:,pst.obs_names[0]].values.reshape(sweep_steps,sweep_steps)

# %%
def get_obj_map(ax,_sweep_x,_sweep_y,_sweep_z,label="objective function",
                levels=[-2,-1,0,0.5],vmin=-2,vmax=0.5,cmap="magma"): 
    """a simple function to plot an objective function surface"""
    cb = ax.pcolormesh(_sweep_x,_sweep_y,_sweep_z,vmin=vmin,vmax=vmax,cmap=cmap)
    plt.colorbar(cb,ax=ax,label=label)
    ax.contour(_sweep_x,_sweep_y,_sweep_z,levels=levels,colors="w")
    
    ax.set_aspect("equal")
    return ax

# %%
fig,ax = plt.subplots(1,1,figsize=(6,5))
_ = get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.set_title("truth",loc="left")
plt.show()
plt.close(fig)

# %% [markdown]
# So that is the true objective function surface with the global minimum at (4,2) and a local minimum at (1,2).
#
# The GPR BO workflow starts by first evaluating an initial population with the complex and expensive to run "model", which here is just the simple hosaki function.  In practice, this will be an expensive and complex process based model.  To make this demo more interesting, we will limit the decision variable search space to not include the global minimum (and really 10 members in the initial population is pretty crazy small - just for demo!).  If we dont limit the search space and use a larger initial population, the GPR process nails it in the first go...

# %%
m_d = "hosaki_model_master"
if os.path.exists(m_d):
    shutil.rmtree(m_d)
pst.pestpp_options["mou_population_size"] = 10
pst.control_data.noptmax = -1
par = pst.parameter_data
par.loc[pst.par_names[0],"parubnd"] = 3
par.loc[pst.par_names[0],"parval1"] = 1.5
pst.write(os.path.join(t_d,"pest.pst"))
num_workers = 1
pyemu.os_utils.start_workers(t_d,"pestpp-mou","pest.pst",
                                 num_workers=num_workers,
                                 master_dir=m_d,worker_root='.',
                                 port=port,ppw_function=ppw_function)
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:27:28
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_model_master"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
#
#   ---  sanity_check warnings  ---
# ...mou_population_size < 20, this is prob too few
# ...continuing initialization...
# ...drawing initial dv population of size:  10
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 10
# ...running population of size  10
#     running model 10 times
#     starting at 06/06/25 08:27:28
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:27:33 remaining file transfers: 0
#
#    10 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0833 run mgr time (min)
#    1 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         3          0      1.38117     0.969375   0.00421403       2.9625
# PAR2                         5          0      1.94232      1.44699    0.0228612      4.58515
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=8 as nearest-to-mean single point
#     with distance of 0.513756 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -0.46484    0.5679451    -1.216399    0.5228356    -1.113185
#
# ... saved initial dv population to  pest.0.dv_pop.csv
#
#   ---  WARNING: less than 20 active population members...might not be enough  ---
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved observation population of size 1 X 1 to 'pest.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:27:28
# finished at 06/06/25 08:27:33
# took 0.0833333 minutes
# 2025-06-06 08:27:29.721217 : trying to connect to localhost:5544...
# 2025-06-06 08:27:29.976857 : connected to localhost:5544

# %% [markdown]
# Now load the initial training input-output pairs

# %%
training_dvpop_fname = os.path.join(m_d,"pest.0.dv_pop.csv")
training_opop_fname = os.path.join(m_d,"pest.0.obs_pop.csv")

# %% [markdown]
# and we can plot them to visual where we have training points on the actual true surface

# %%
training_dvpop = pd.read_csv(training_dvpop_fname,index_col=0)
training_opop = pd.read_csv(training_opop_fname,index_col=0)
fig,ax = plt.subplots(1,1,figsize=(6,5))
get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
ax.set_title("true objective function surface with training points")
plt.show()
plt.close(fig)

# %% [markdown]
# Those white triangles are the places where we have actually run the model - in practice we will never have the colormap or the contours - those are just to help us understand what is happening...and remember: that is a purposefully sparse training dataset!
#
# This function is where the magic happens: we use the decision variable population and resulting output/observation population to setup the GPR emulation process.  Note that `pyemu.helpers.prep_for_gpr()` function setups and training a GPR emulator for each non-zero weighted observation in the control file...

# %%
def prep_for_gpr(t_d,dvpops,opops,gpr_t_d,noptmax=-1):
    # this helper does the heavy lifting.  We are including the optional GPR emulated standard deviations
    # as "observations".  These quantities are the standard deviation of the emulated objective function value
    # with respect to the GPR process - this is a unique and very powerful aspect of GPR vs other
    #data-driven techniques.  We will use these obs to visualize the uncertainty in the 
    # GPR objectve function surface later...
    pyemu.helpers.prep_for_gpr(os.path.join(t_d,"pest.pst"),dvpops,opops,t_d=t_d,gpr_t_d=gpr_t_d,plot_fits=True,
                               include_emulated_std_obs=True)
    # now load the newly created gpr-based pst file:
    gpst = pyemu.Pst(os.path.join(gpr_t_d,"pest.pst"))
    #and copy the sweep input file that lets us run the full response surface
    # in practice, you dont need this either...
    shutil.copy2(os.path.join(sweep_d,"sweep_in.csv"),os.path.join(gpr_t_d,"sweep_in.csv"))
    # some bits and bobs:
    gpst.control_data.noptmax = noptmax
    gpst.pestpp_options["ies_include_base"] = False
    gpst.pestpp_options["mou_save_population_every"] = 1
    gpst.pestpp_options.pop("mou_dv_population_file",None)
    par = gpst.parameter_data
    par.loc[:,"parlbnd"] = 0.0
    par.loc[:,"parubnd"] = 5.0
    par.loc[:,"parval1"] = 2.5    
    
    gpst.write(os.path.join(gpr_t_d,"pest.pst"),version=2)
    return gpst

# %% [markdown]
# One important consideration here: In this simple demo, we only have one objective.  That means we have to be careful not to drive the emulator to a single best-fit solution (which we do by using only a few generations when we run mou), but we also need to sure that we start the emulator-driven mou runs with a fully dispersed initial population.  But!  In a multiobjective run, the final generation for mou is naturally disperesed because of the pareto frontier search, so in the multiobjective setting, we probably want to start the emulated mou run with the existing population to keep us from having to research all of decision variable space for the nondominated solutions.  This isn't a hard-and-fast rule, but it seems to be generally applicable
#
# The GPR helper in pyemu accepts a list of input and output filenames to make it easier to repeatedly retrain the GPR emulators:

# %%
training_dvpop_fnames = [training_dvpop_fname]
training_opop_fnames = [training_opop_fname]

# %%
gpr_t_d = t_d + "_gpr"
gpst = prep_for_gpr(t_d,training_dvpop_fnames,training_opop_fnames,gpr_t_d)
# we only need these files in memory so we can use the speed of PyPestWorker later....
input_df = pd.read_csv(os.path.join(gpr_t_d,"gpr_input.csv"),index_col=0)
mdf = pd.read_csv(os.path.join(gpr_t_d,"gprmodel_info.csv"),index_col=0)
mdf["model_fname"] = mdf.model_fname.apply(lambda x: os.path.join(gpr_t_d,x))
# Out:
# using all adjustable parameters as inputs
# input names: ['par1', 'par2']
# 'mou_objectives' not found in ++ options, using all ineq tagged non-zero weighted obs as objectives
# objectives: ['sim']
# constraints: []
# loading input and output files
# ...loaded hosaki_model_master/pest.0.dv_pop.csv hosaki_model_master/pest.0.obs_pop.csv
# aggregated training dataset shape (10, 3) saved to hosaki_template/pest.pst.aggresults.csv
# Hyperparameter(name='length_scale', value_type='numeric', bounds=array([[1.e-04, 1.e+04]]), n_elements=1, fixed=False)
# training GPR for sim with 10 data points
# WARNING: not applying StandardScalar transformation - user beware!
# sim optimized kernel: Matern(length_scale=3.84, nu=0.5)
# ...plotting fits for sim
# GPR model info saved to hosaki_template_gpr/gprmodel_info.csv
# noptmax:0, npar_adj:2, nnz_obs:1
# saved gpr pst: pest.pst in gpr_t_d hosaki_template_gpr
# ./pestpp-mou pest.pst
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/pst/pst_utils.py:922: UserWarning: error processing instruction file hosaki_template_gpr/gpr_output.csv.ins, trying inschek: output file 'hosaki_template_gpr/gpr_output.csv' not found
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:27:51
# ...processing command line: ' ./pestpp-mou pest.pst'
# ...using serial run manager
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template_gpr"
# processing control file pest.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  1
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...less_than inequality defined for observations:  1
# ...running control file parameter values
# ...running population of size  1
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 06/06/25 08:27:51 processing template files with 1 threads...
# 06/06/25 08:27:51 done, took 0 seconds
# 06/06/25 08:27:51 calling forward run command(s)
# 06/06/25 08:27:51 calling forward run command: 'python forward_run.py'
# ...pid: 49757
# ...exit_code: 49757
# ...status: 0
# 06/06/25 08:27:52 forward run command(s) finished, took 0.881 seconds
# 06/06/25 08:27:52 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 06/06/25 08:27:52 done, took 0 seconds
#
#
# -->06/06/25 08:27:52 run complete, took: 0.881 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 0.881 seconds
#
#
#
#
# ...saving results from control file parameter value run to  pest.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        17422.2              0        17422.2        17422.2
#          actual        17422.2              0        17422.2        17422.2
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  1.74e+04         0  1.74e+04  1.74e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#   ---  control file parameter objective function summary:   ---
# using member BASE as nearest-to-mean single point
#     with distance of 0 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.025878            0    -1.025878    -1.025878    -1.025878
#
# iteration 0: 0 obs constraints and 0 prior info constraints not satisfied, see rec file for listing
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:27:51
# finished at 06/06/25 08:27:52
# took 0 minutes
# noptmax:-1, npar_adj:2, nnz_obs:1
# noptmax:-1, npar_adj:2, nnz_obs:1

# %%
gpst.observation_data
# Out:
#                 obsnme        obsval  weight     obgnme  extra
# obsnme
# sim                sim -2.345812e+00   100.0  less_than    NaN
# sim_gprstd  sim_gprstd  1.000000e+10     0.0     obgnme    NaN

# %% [markdown]
# We see the original "sim" observation (which is the objective function we are trying to minimize), but we also see the optional GPR-estimated standard devivation
#
# Let's see what was created in the new GPR-based template directory:

# %%
os.listdir(gpr_t_d)
# Out:
# ['pest.pargp_data.csv',
#  'pest.obs.csv',
#  'gpr_input.csv',
#  'pest.base.rei',
#  'pest.phi.actual.csv',
#  'pest.rec',
#  'pestpp-opt',
#  'pest.log',
#  'forward_run.py',
#  'gpr_fits.pdf',
#  'pest.phi.lambda.csv',
#  'gprmodel_info.csv',
#  'pest.pst.obj_0.pkl',
#  'pest.pst',
#  'gpr_input.csv.tpl',
#  'gpr_aggregate_training_data.csv',
#  'gpr_output.csv.ins',
#  'pestpp-sen',
#  'gpr_output.csv',
#  'pestpp-sqp',
#  'pest.rns',
#  'pestpp-da',
#  'pestpp-glm',
#  'pest.phi.regul.csv',
#  'pest.par_data.csv',
#  'pest.insfile_data.csv',
#  'pest.phi.composite.csv',
#  'pest.rst',
#  'pest.phi.group.csv',
#  'pest.phi.meas.csv',
#  'pest.base.par',
#  'pestpp-ies',
#  'pestpp-mou',
#  'pest.obs_data.csv',
#  'pest.tplfile_data.csv',
#  'pestpp-swp',
#  'run.info',
#  'sweep_in.csv']

# %% [markdown]
# two very important files in that dir:  the new forward run python script and a series of pickle files, one per objective and one per active constraint in the optimization problem.  Essentially, we need to build a GPR-based emulator for each output that is relevant to the optimization problem.  We also dont want to rebuild these emulators every time we run the model, so we store the trained GPR emulators in pickle files and load them up as needed:

# %%
with open(os.path.join(gpr_t_d,"forward_run.py"),'r') as f:
    for line in f:
        print(line,end="")
# Out:
# import pandas as pd
# import os
# import pickle
# import numpy as np
# def get_gpr_model_dict(mdf):
#     import pickle
#     gpr_model_dict = {}
#     for output_name,model_fname in zip(mdf.output_name,mdf.model_fname):
#         gaussian_process = pickle.load(open(model_fname,'rb'))
#         gpr_model_dict[output_name] = gaussian_process
#     return gpr_model_dict
#
# def emulate_with_gpr(input_df,mdf,gpr_model_dict):
#     mdf.loc[:,"sim"] = np.nan
#     mdf.loc[:,"sim_std"] = np.nan
#     for output_name,gaussian_process in gpr_model_dict.items():
#         sim = gaussian_process.predict(np.atleast_2d(input_df.parval1.values),return_std=True)
#         mdf.loc[output_name,"sim"] = sim[0]
#         mdf.loc[output_name,"sim_std"] = sim[1]
#     return mdf
#
# def gpr_forward_run():
#     """the function to evaluate a set of inputs thru the GPR emulators.\
#     This function gets added programmatically to the forward run process"""
#     import pandas as pd
#     input_df = pd.read_csv("gpr_input.csv",index_col=0)
#     mdf = pd.read_csv("gprmodel_info.csv",index_col=0)
#     gpr_model_dict = get_gpr_model_dict(mdf)
#     mdf = emulate_with_gpr(input_df,mdf,gpr_model_dict)
#     mdf.loc[:,["output_name","sim","sim_std"]].to_csv("gpr_output.csv",index=False)
#     return mdf
# if __name__ == '__main__':
#     gpr_forward_run()

# %% [markdown]
# So we simply loop over all relevant model outputs that have a GPR emulator and "emulate" the value of the model output given the current decision variable values.  easy as!

# %% [markdown]
# Now, just for learning, lets sweep over decision variable space but evaluate the GPR emulated objective function value.  You would never do this in practice, but it can be informative:

# %%
gpr_sweep_d = sweep_d+"_gpr"
num_workers = 10
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_sweep_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})
# Out:
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:27:52
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep_gpr"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:27:52
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:28:18 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.437 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        31637.5        11630.2        13001.5        79593.6
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  3.16e+04  1.16e+04   1.3e+04  7.96e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        31637.5        11630.2        13001.5        79593.6
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  3.16e+04  1.16e+04   1.3e+04  7.96e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:27:52
# finished at 06/06/25 08:28:18
# took 0.433333 minutes
# 2025-06-06 08:27:53.880438 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.136168 : connected to localhost:5544
# 2025-06-06 08:27:53.923165 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.178489 : connected to localhost:5544
# 2025-06-06 08:27:53.887293 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.142958 : connected to localhost:5544
# 2025-06-06 08:27:53.886496 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.142949 : connected to localhost:5544
# 2025-06-06 08:27:53.899448 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.154908 : connected to localhost:5544
# 2025-06-06 08:27:53.924139 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.179543 : connected to localhost:5544
# 2025-06-06 08:27:53.921397 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.176831 : connected to localhost:5544
# 2025-06-06 08:27:53.914572 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.170027 : connected to localhost:5544
# 2025-06-06 08:27:53.905820 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.161255 : connected to localhost:5544
# 2025-06-06 08:27:53.926831 : trying to connect to localhost:5544...
# 2025-06-06 08:27:54.182562 : connected to localhost:5544

# %% [markdown]
# Just a helper function to visual the results of the GPR (re-)training:

# %%
def plot_gpr_sweep_results(_gpr_sweep_d,_training_dvpop):
    #load the gpr sweep results to viz the emulated objective function surface
    sweep_gpr_pe = pd.read_csv(os.path.join(_gpr_sweep_d,"pest.0.par.csv"),index_col=0)
    sweep_gpr_oe = pd.read_csv(os.path.join(_gpr_sweep_d,"pest.0.obs.csv"),index_col=0)
    gpr_sweep_x = sweep_gpr_pe.loc[:,gpst.par_names[0]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_y = sweep_gpr_pe.loc[:,gpst.par_names[1]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_z = sweep_gpr_oe.loc[:,gpst.obs_names[0]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_stdev_z = sweep_gpr_oe.loc[:,gpst.obs_names[1]].values.reshape(sweep_steps,sweep_steps)
    
    # plot it up:
    fig, axes = plt.subplots(2,2,figsize=(10,8))
    axes = axes.flatten()
    get_obj_map(axes[0],sweep_x,sweep_y,sweep_z)
    get_obj_map(axes[1],gpr_sweep_x,gpr_sweep_y,gpr_sweep_z)
    axes[1].scatter(_training_dvpop.loc[:,pst.par_names[0]],_training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
    diff = sweep_z-gpr_sweep_z
    amax = np.abs(diff).max()
    get_obj_map(axes[2],gpr_sweep_x,gpr_sweep_y,sweep_z-gpr_sweep_z,label="truth minus emulated",levels=None,vmin=-amax,vmax=amax,cmap="bwr")
    get_obj_map(axes[3],gpr_sweep_x,gpr_sweep_y,gpr_sweep_stdev_z,label="GPR stdev",levels=None,
                vmin=gpr_sweep_stdev_z.min(),vmax=gpr_sweep_stdev_z.max(),cmap="jet")
    axes[2].scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
    
    axes[0].set_title("truth",loc="left")
    axes[1].set_title("emulated with training points",loc="left")
    axes[2].set_title("difference with training points",loc="left")
    axes[3].set_title("GPR standard deviation",loc="left")
    plt.show()

# %%
plot_gpr_sweep_results(gpr_sweep_d,training_dvpop)

# %% [markdown]
# OK!  now we can see what's happening - the emulated objective function surface is strongly controlled by the location of the training data points, and, is this case, its not a good representation of the truth surface...yet...it should also be clear that the uncertainty in the GPR emulation is lowest near the training points but is highly uncertain as we move away from the training - just like geostatistics!
#
# But now lets run pestpp-mou on the GPR emulated model.  This is usually quite fast, especially if the process model that is being emulated takes more than a few mins to run...

# %%
gpst.control_data.noptmax = 8
gpst.pestpp_options["mou_population_size"] = 40
gpst.write(os.path.join(gpr_t_d,"pest.pst"))
gpr_m_d = gpr_t_d.replace("template","master")
num_workers = 3
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-mou","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_m_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})
# Out:
# noptmax:8, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:28:19
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_master_gpr"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  40
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 40
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:19
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:28:25 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.111 run mgr time (min)
#    3 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      1.94967      1.37767   0.00702338      4.93751
# PAR2                         5          0       2.5199      1.41193     0.293313      4.98586
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=11 as nearest-to-mean single point
#     with distance of 0.687753 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.5830199    0.3505342    -1.002691    0.1839455   -0.9962324
#
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.0.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:25
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:29 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0595 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.1.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.1.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.1.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.48963      1.04669     0.624848      4.58515
# PAR2                         5          0      3.01942     0.962848      1.39972      4.81858
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -0.53996    -27.6949    0.352356     7.13631   -0.617825    -8796.68
# PAR2                  -0.499516    -19.8228     0.16728      3.3551    -1.10641     -377.21
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=49_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.8821999    0.1134569    -1.163557   -0.6953013    -1.163557
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                      0.29918           0    0.879247     477.993    0.160867           0    0.167325           0
#
# ...number of feasible solutions at the end of generation 1: 2
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:29
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:33 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.2.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.2.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.30849     0.842735     0.836285      4.01479
# PAR2                         5          0      2.96037     0.711394      1.56187      4.13413
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.181139     7.27572    0.570361     12.4393   -0.211438    -33.8382
# PAR2                   0.059046     1.95554    0.684451     14.2044   -0.162152    -11.5846
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=49_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.9613708   0.06903969    -1.163557   -0.8618029    -1.163557
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0791709           0    0.166502           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 2: 80
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:33
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:36 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0593 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.3.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.3.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.3.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.3.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.22015      0.70651     0.838135      3.60135
# PAR2                         5          0      2.85211     0.623077      1.68863      3.90416
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0883419     3.82682    0.413444      10.298 -0.00184933   -0.221137
# PAR2                   0.108259     3.65693    0.229968     5.56268   -0.126765    -8.11622
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=207_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.015888   0.06003349      -1.1804   -0.9279244      -1.1804
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0545175           0   0.0661215           0   0.0168425           0   0.0168425           0
#
# ...number of feasible solutions at the end of generation 3: 2
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:36
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:40 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0593 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.4.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.4.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.36086     0.658161     0.838135      3.60135
# PAR2                         5          0      2.79033     0.488134      1.80361       3.6563
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.140706    -6.33768           0           0           0           0
# PAR2                   0.061784     2.16625    0.247864     6.34871   -0.114971    -6.80849
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=207_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.056415   0.05498532      -1.1804   -0.9908045      -1.1804
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0405264           0     0.06288           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 80
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:40
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:43 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.5.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.5.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       2.5424     0.636803     0.838135      3.36541
# PAR2                         5          0      2.85782     0.379735      1.80361       3.4363
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.181539    -7.68952    0.235935     6.55129           0           0
# PAR2                 -0.0674906    -2.41873    0.219996     6.01691           0           0
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=207_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.08932   0.05050247      -1.1804    -1.026854      -1.1804
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0329051           0   0.0360491           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 5: 79
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:43
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:47 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0593 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.6.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.6.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.6.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.6.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.96521     0.276949      2.19136      3.35895
# PAR2                         5          0      3.02049     0.191213       2.5285      3.41654
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.422812    -16.6305  0.00645916    0.191928    -1.35323    -161.457
# PAR2                  -0.162667    -5.69199   0.0197646    0.575171   -0.724899    -40.1917
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=6_MEMBER=495_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.123887   0.03802295    -1.185944    -1.055306    -1.185944
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0345671           0   0.0284523           0  0.00554398           0  0.00554398           0
#
# ...number of feasible solutions at the end of generation 6: 2
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:47
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:50 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0593 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.7.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.7.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.7.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.94168     0.212266      2.48433      3.25734
# PAR2                         5          0      2.94169     0.148272       2.6459      3.25762
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0235307     0.79356    0.101613     3.02515   -0.292967    -13.3692
# PAR2                  0.0787925      2.6086    0.158912     4.65125   -0.117391     -4.6427
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=7_MEMBER=549_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.143784   0.02487039    -1.208554    -1.101593    -1.208554
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.019897           0   0.0462871           0   0.0226096           0   0.0226096           0
#
# ...number of feasible solutions at the end of generation 7: 2
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:28:50
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:28:54 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.8.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       2.9125     0.136983      2.63571       3.1475
# PAR2                         5          0       2.9435     0.118282      2.73522      3.19775
#
#
#   ---  generation 8 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0291772    0.991856    0.109842     3.37215    -0.15138    -6.09341
# PAR2                -0.00180869  -0.0614847   0.0598738     1.83796  -0.0893278    -3.37609
#
#
#   ---  generation 8 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=7_MEMBER=549_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.165769   0.01811197    -1.208554    -1.137567    -1.208554
#
#
#   ---  generation 8 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0219853           0   0.0359741           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 8: 80
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:28:19
# finished at 06/06/25 08:28:54
# took 0.583333 minutes
# 2025-06-06 08:28:20.860345 : trying to connect to localhost:5544...
# 2025-06-06 08:28:21.116055 : connected to localhost:5544
# 2025-06-06 08:28:20.860371 : trying to connect to localhost:5544...
# 2025-06-06 08:28:21.116062 : connected to localhost:5544
# 2025-06-06 08:28:20.860358 : trying to connect to localhost:5544...
# 2025-06-06 08:28:21.116047 : connected to localhost:5544

# %% [markdown]
# Now lets plot how the pestpp-mou population evolves across the emulated surface, but also plot it on the true surface just to help us understand what is happening

# %%
def plot_gpr_mou_results(_gpr_m_d,_gpr_sweep_d):
    sweep_gpr_pe = pd.read_csv(os.path.join(_gpr_sweep_d,"pest.0.par.csv"),index_col=0)
    sweep_gpr_oe = pd.read_csv(os.path.join(_gpr_sweep_d,"pest.0.obs.csv"),index_col=0)
    gpr_sweep_x = sweep_gpr_pe.loc[:,gpst.par_names[0]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_y = sweep_gpr_pe.loc[:,gpst.par_names[1]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_z = sweep_gpr_oe.loc[:,gpst.obs_names[0]].values.reshape(sweep_steps,sweep_steps)
    gpr_sweep_stdev_z = sweep_gpr_oe.loc[:,gpst.obs_names[1]].values.reshape(sweep_steps,sweep_steps)
    
    gpr_dvpops = [os.path.join(_gpr_m_d,f) for f in os.listdir(_gpr_m_d) if len(f.split('.')) == 4 and f.endswith("dv_pop.csv") and "archive" not in f]
    gpr_dvpops_itr = [int(f.split(".")[1]) for f in gpr_dvpops]
    gpr_dvpops = {itr:pd.read_csv(f,index_col=0) for itr,f in zip(gpr_dvpops_itr,gpr_dvpops)}
    for itr in range(max(gpr_dvpops_itr)):
        fig,axes = plt.subplots(1,2,figsize=(10,4))
        ax = axes[0]
        get_obj_map(ax,sweep_x,sweep_y,sweep_z)
        ax.scatter(gpr_dvpops[itr].loc[:,gpst.par_names[0]],gpr_dvpops[itr].loc[:,gpst.par_names[1]],marker='.',c='w',s=10)
        ax.set_title("truth generation {0}".format(itr),loc="left")
        ax = axes[1]
        get_obj_map(ax,gpr_sweep_x,gpr_sweep_y,gpr_sweep_z)
        ax.scatter(gpr_dvpops[itr].loc[:,gpst.par_names[0]],gpr_dvpops[itr].loc[:,gpst.par_names[1]],marker='.',c='w',s=10)
        ax.set_title("emulated generation {0}".format(itr),loc="left")
        plt.show()
        plt.close(fig)

# %%
plot_gpr_mou_results(gpr_m_d,gpr_sweep_d)

# %% [markdown]
# So just what you expected?  Essentially pestpp-mou converged to the minimum of the objective function we gave it, which is the emulated objective function...at this stage the emulated objective function is a poor representation of the truth objective function....
#
# Now this where some more cleverness happens:  Lets take that last emulated decision variable population and actually run it thru the complex "model" (which in this case is just the hosaki function...).  This is so that we can "in-fill" our GPR emulator with this new points in decision variable space.  In practice, a lot more cleverness needs to happen to actually decide which points, but for this lil demo, it works...

# %%
gpr_dvpops = [os.path.join(gpr_m_d,f) for f in os.listdir(gpr_m_d) if len(f.split('.')) == 4 and f.endswith("dv_pop.csv") and "archive" not in f]
gpr_dvpops_itr = [int(f.split(".")[1]) for f in gpr_dvpops]
gpr_dvpops = {itr:pd.read_csv(f,index_col=0) for itr,f in zip(gpr_dvpops_itr,gpr_dvpops)}
# only use the first 10 members of the emulated population to evaluate in the model to make things more interesting
gpr_dvpops[max(gpr_dvpops_itr)].iloc[:10].to_csv(os.path.join(t_d,"retrain_1_dvpop.csv"))
pst.pestpp_options["mou_dv_population_file"] = "retrain_1_dvpop.csv"
pst.control_data.noptmax = -1
pst.write(os.path.join(t_d,"pest.pst"))
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1

# %%
m_d += "_1"
num_workers = 1
pyemu.os_utils.start_workers(t_d,"pestpp-mou","pest.pst",
                                 num_workers=num_workers,
                                 master_dir=m_d,worker_root='.',
                                 port=port,ppw_function=ppw_function)
# Out:
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:28:56
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_model_master_1"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
#
#   ---  sanity_check warnings  ---
# ...mou_population_size < 20, this is prob too few
# ...continuing initialization...
# ...loading dv population from csv file retrain_1_dvpop.csv
# ...dv population with 10 members read from 'retrain_1_dvpop.csv'
#
# ...previous generation numbers detected in dv population, fast forwarding generation counter to 8
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 10
# ...running population of size  10
#     running model 10 times
#     starting at 06/06/25 08:28:56
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:29:00 remaining file transfers: 0
#
#    10 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0804 run mgr time (min)
#    1 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         3          0      3.12076     0.550148      2.23594      4.49221
# PAR2                         5          0      2.96842     0.363989      2.54599      3.97888
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=8_MEMBER=611_PSO as nearest-to-mean single point
#     with distance of 0.162716 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.270926    0.2931741    -1.752183   -0.7493037    -1.361138
#
# ... saved initial dv population to  pest.0.dv_pop.csv
#
#   ---  WARNING: less than 20 active population members...might not be enough  ---
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved observation population of size 1 X 1 to 'pest.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:28:56
# finished at 06/06/25 08:29:00
# took 0.0666667 minutes
# 2025-06-06 08:28:56.811228 : trying to connect to localhost:5544...
# 2025-06-06 08:28:57.066773 : connected to localhost:5544

# %% [markdown]
# Now load the newly evaluated training points:

# %%
training_dvpop_fname1 = os.path.join(m_d,"pest.0.dv_pop.csv")
training_opop_fname1 = os.path.join(m_d,"pest.0.obs_pop.csv")

# %% [markdown]
# And combine these new points with the points we already had (the original few places where we ran the model at the beginning):

# %%
training_dvpop1 = pd.read_csv(training_dvpop_fname1,index_col=0)
training_opop1 = pd.read_csv(training_opop_fname1,index_col=0)
training_dvpop = pd.concat([training_dvpop,training_dvpop1])
training_opop = pd.concat([training_opop,training_opop1])

fig,ax = plt.subplots(1,1,figsize=(6,5))
get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
plt.show()
plt.close(fig)

# %% [markdown]
# See how we have combined the original points and the new points?
#
# Now lets re-do the GPR training process with this combined decision variable and output/observation population

# %%
training_dvpop_fnames.append(training_dvpop_fname1)
training_opop_fnames.append(training_opop_fname1)
gpr_t_d = t_d + "_gpr1"
gpst = prep_for_gpr(t_d,training_dvpop_fnames,training_opop_fnames,gpr_t_d)
# we only need these files in memory so we can use the speed of PyPestWorker later....
input_df = pd.read_csv(os.path.join(gpr_t_d,"gpr_input.csv"),index_col=0)
mdf = pd.read_csv(os.path.join(gpr_t_d,"gprmodel_info.csv"),index_col=0)
mdf["model_fname"] = mdf.model_fname.apply(lambda x: os.path.join(gpr_t_d,x))
# Out:
# using all adjustable parameters as inputs
# input names: ['par1', 'par2']
# 'mou_objectives' not found in ++ options, using all ineq tagged non-zero weighted obs as objectives
# objectives: ['sim']
# constraints: []
# loading input and output files
# ...loaded hosaki_model_master/pest.0.dv_pop.csv hosaki_model_master/pest.0.obs_pop.csv
# ...loaded hosaki_model_master_1/pest.0.dv_pop.csv hosaki_model_master_1/pest.0.obs_pop.csv
# aggregated training dataset shape (20, 3) saved to hosaki_template/pest.pst.aggresults.csv
# Hyperparameter(name='length_scale', value_type='numeric', bounds=array([[1.e-04, 1.e+04]]), n_elements=1, fixed=False)
# training GPR for sim with 20 data points
# WARNING: not applying StandardScalar transformation - user beware!
# sim optimized kernel: Matern(length_scale=6.84, nu=0.5)
# ...plotting fits for sim
# GPR model info saved to hosaki_template_gpr1/gprmodel_info.csv
# noptmax:0, npar_adj:2, nnz_obs:1
# saved gpr pst: pest.pst in gpr_t_d hosaki_template_gpr1
# ./pestpp-mou pest.pst
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/pst/pst_utils.py:922: UserWarning: error processing instruction file hosaki_template_gpr1/gpr_output.csv.ins, trying inschek: output file 'hosaki_template_gpr1/gpr_output.csv' not found
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:29:01
# ...processing command line: ' ./pestpp-mou pest.pst'
# ...using serial run manager
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template_gpr1"
# processing control file pest.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  1
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...less_than inequality defined for observations:  1
# ...running control file parameter values
# ...running population of size  1
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 06/06/25 08:29:01 processing template files with 1 threads...
# 06/06/25 08:29:01 done, took 0 seconds
# 06/06/25 08:29:01 calling forward run command(s)
# 06/06/25 08:29:01 calling forward run command: 'python forward_run.py'
# ...pid: 49868
# ...exit_code: 49868
# ...status: 0
# 06/06/25 08:29:02 forward run command(s) finished, took 0.88 seconds
# 06/06/25 08:29:02 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 06/06/25 08:29:02 done, took 0 seconds
#
#
# -->06/06/25 08:29:02 run complete, took: 0.88 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 0.88 seconds
#
#
#
#
# ...saving results from control file parameter value run to  pest.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        20310.4              0        20310.4        20310.4
#          actual        20310.4              0        20310.4        20310.4
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.03e+04         0  2.03e+04  2.03e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#   ---  control file parameter objective function summary:   ---
# using member BASE as nearest-to-mean single point
#     with distance of 0 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.9206656            0   -0.9206656   -0.9206656   -0.9206656
#
# iteration 0: 0 obs constraints and 0 prior info constraints not satisfied, see rec file for listing
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:29:01
# finished at 06/06/25 08:29:02
# took 0 minutes
# noptmax:-1, npar_adj:2, nnz_obs:1
# noptmax:-1, npar_adj:2, nnz_obs:1

# %% [markdown]
# Ok, now let's also re-sweep over the emulated surface to see how much better our approximation to the true objective function surface (remember dont do this in practice!  we are just doing it here to help build understanding):

# %%
gpr_sweep_d = sweep_d+"_gpr1"
num_workers = 10
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_sweep_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})
# Out:
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:29:02
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep_gpr1"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:29:02
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:29:29 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.438 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        27513.3        13664.2        3970.14        79739.3
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.75e+04  1.37e+04  3.97e+03  7.97e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        27513.3        13664.2        3970.14        79739.3
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.75e+04  1.37e+04  3.97e+03  7.97e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:29:02
# finished at 06/06/25 08:29:29
# took 0.433333 minutes
# 2025-06-06 08:29:04.470301 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.724580 : connected to localhost:5544
# 2025-06-06 08:29:04.482926 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.738392 : connected to localhost:5544
# 2025-06-06 08:29:04.519369 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.774681 : connected to localhost:5544
# 2025-06-06 08:29:04.508691 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.764590 : connected to localhost:5544
# 2025-06-06 08:29:04.503907 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.759649 : connected to localhost:5544
# 2025-06-06 08:29:04.500691 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.756141 : connected to localhost:5544
# 2025-06-06 08:29:04.511467 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.767115 : connected to localhost:5544
# 2025-06-06 08:29:04.541668 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.797580 : connected to localhost:5544
# 2025-06-06 08:29:04.534434 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.790126 : connected to localhost:5544
# 2025-06-06 08:29:04.533931 : trying to connect to localhost:5544...
# 2025-06-06 08:29:04.789360 : connected to localhost:5544

# %% [markdown]
# And now visualize these new surfaces with the current training dataset:

# %%
plot_gpr_sweep_results(gpr_sweep_d,training_dvpop)

# %% [markdown]
# Comparing this to the original emulated surface, we can see that our emulated objective function surface has improved dramatically!
#
# Now let's run pestpp-mou on this improved emulated model and visualize how pestpp-mou navigates this new emulated surface:

# %%
gpst.control_data.noptmax = 8
gpst.pestpp_options["mou_population_size"] = 40
gpst.write(os.path.join(gpr_t_d,"pest.pst"))
gpr_m_d = gpr_t_d.replace("template","master")
num_workers = 3
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-mou","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_m_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})
plot_gpr_mou_results(gpr_m_d,gpr_sweep_d)
# Out:
# noptmax:8, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:29:29
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_master_gpr1"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  40
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 40
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:29
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:30 mn:0     runs(C0    |F0    |T0    ) agents(R0   |W0   |U0   ) 0
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:29:36 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.112 run mgr time (min)
#    3 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      1.94967      1.37767   0.00702338      4.93751
# PAR2                         5          0       2.5199      1.41193     0.293313      4.98586
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=11 as nearest-to-mean single point
#     with distance of 0.687753 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.6543112    0.4421583    -1.659644    0.1978355   -0.7427473
#
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.0.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:36
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:40 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.1.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.52894      1.15834      1.22759            5
# PAR2                         5          0      2.54372     0.833209      1.44575      4.56239
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -1.57927    -81.0017  -0.0624922    -1.26566    -1.22057    -17378.7
# PAR2                 -0.0238133   -0.945008    0.423466     8.49335    -1.15244    -392.903
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=10 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.127943    0.2124781    -1.659644   -0.8537041    -1.659644
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.473632           0     1.05154     531.522           0           0    0.916897           0
#
# ...number of feasible solutions at the end of generation 1: 80
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:40
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:43 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.2.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.2.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.14698     0.757835      2.59788            5
# PAR2                         5          0      2.46536     0.626721      1.40098      3.82048
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -0.61804    -17.5135           0           0    -1.37029    -111.624
# PAR2                  0.0783589     3.08049    0.741911     16.2614   0.0447647      3.0963
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=10 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.234008     0.148576    -1.659644    -1.069721    -1.659644
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.106065           0    0.216017           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 2: 79
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:43
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:47 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0595 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.3.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.3.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.85367     0.643042      2.80469            5
# PAR2                         5          0      2.42411     0.424337      1.66327      3.36239
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.293308      7.0728           0           0   -0.206815    -7.96092
# PAR2                  0.0412426     1.67288     0.45809     11.9904   -0.262282    -18.7213
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=10 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.349828    0.1429145    -1.659644    -1.164442    -1.659644
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                      0.11582           0   0.0947206           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 3: 80
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:47
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:50 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.4.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.4.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.7138       0.4365      2.90723      4.70309
# PAR2                         5          0       2.5341     0.416577      1.83529       3.3472
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.139872     3.62957    0.296908     5.93816   -0.102538    -3.65593
# PAR2                  -0.109983    -4.53702   0.0151888    0.451725   -0.172023    -10.3425
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=10 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.42874    0.1182155    -1.659644    -1.235215    -1.659644
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0789119           0   0.0707735           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 80
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:50
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:54 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0595 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.5.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.5.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.5.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.5.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.69872     0.334908      2.97644      4.26176
# PAR2                         5          0      2.55343     0.361265      1.96506      3.19806
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.015079    0.406027    0.441331     9.38385  -0.0692101    -2.38062
# PAR2                 -0.0193301   -0.762801    0.149137     4.45559    -0.12977    -7.07081
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=5_MEMBER=421_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.479859   0.09171086    -1.682031    -1.365584    -1.682031
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0511191           0    0.130369           0   0.0223865           0   0.0223865           0
#
# ...number of feasible solutions at the end of generation 5: 2
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:54
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:29:58 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00422 avg run time (min) : 0.0593 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.6.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.6.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.6.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.6.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.60118     0.279491      3.14499      4.06298
# PAR2                         5          0      2.54858     0.273664      2.05024       3.0339
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0975392     2.63711    0.198777      4.6642   -0.168549    -5.66277
# PAR2                 0.00484429    0.189717    0.164168     5.13337  -0.0851848    -4.33497
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=6_MEMBER=505_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.547464   0.08260891    -1.718835    -1.437058    -1.718835
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0676046           0   0.0714736           0   0.0368042           0   0.0368042           0
#
# ...number of feasible solutions at the end of generation 6: 2
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:29:58
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:01 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.7.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.46005     0.216176      3.14421      3.91597
# PAR2                         5          0      2.57672     0.229047      2.16692      3.00251
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.141137     3.91919     0.14701     3.61827 0.000786118   0.0249959
# PAR2                 -0.0281389     -1.1041   0.0313841     1.03445   -0.116673    -5.69068
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=6_MEMBER=505_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.587957   0.06435338    -1.718835    -1.505484    -1.718835
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0404933           0   0.0684261           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 7: 80
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:30:01
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:05 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0594 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.8.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.8.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.8.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.46783     0.169012      3.18432      3.78603
# PAR2                         5          0      2.58784     0.181886      2.23684      2.92282
#
#
#   ---  generation 8 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.00778497   -0.224996    0.129943     3.31828  -0.0401188    -1.27596
# PAR2                  -0.011115   -0.431362   0.0796944     2.65426  -0.0699211    -3.22675
#
#
#   ---  generation 8 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=8_MEMBER=647_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.626446   0.04685705    -1.728804    -1.545246    -1.728804
#
#
#   ---  generation 8 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0384894           0   0.0397623           0  0.00996905           0  0.00996905           0
#
# ...number of feasible solutions at the end of generation 8: 2
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:29:29
# finished at 06/06/25 08:30:05
# took 0.583333 minutes
# 2025-06-06 08:29:31.586384 : trying to connect to localhost:5544...
# 2025-06-06 08:29:31.841989 : connected to localhost:5544
# 2025-06-06 08:29:31.586347 : trying to connect to localhost:5544...
# 2025-06-06 08:29:31.841984 : connected to localhost:5544
# 2025-06-06 08:29:31.586371 : trying to connect to localhost:5544...
# 2025-06-06 08:29:31.841995 : connected to localhost:5544

# %% [markdown]
# Now lets do this whole process a few times:

# %%
i = 2
gpr_t_d = t_d + "_gpr{0}".format(i-1)
gpr_m_d = gpr_t_d.replace("template","master")
gpr_dvpops = [os.path.join(gpr_m_d,f) for f in os.listdir(gpr_m_d) if len(f.split('.')) == 4 and f.endswith("dv_pop.csv") and "archive" not in f]
gpr_dvpops_itr = [int(f.split(".")[1]) for f in gpr_dvpops]
gpr_dvpops = {itr:pd.read_csv(f,index_col=0) for itr,f in zip(gpr_dvpops_itr,gpr_dvpops)}
# only use the first 10 members of the emulated population to evaluate in the model to make things more interesting
gpr_dvpops[max(gpr_dvpops_itr)].iloc[:10,:].to_csv(os.path.join(t_d,"retrain_{0}_dvpop.csv".format(i)))
pst.pestpp_options["mou_dv_population_file"] = "retrain_{0}_dvpop.csv".format(i)
pst.control_data.noptmax = -1
pst.write(os.path.join(t_d,"pest.pst"))
m_d = "hosaki_model_{0}".format(i)
num_workers = 1
pyemu.os_utils.start_workers(t_d,"pestpp-mou","pest.pst",
                                 num_workers=num_workers,
                                 master_dir=m_d,worker_root='.',
                                 port=port,ppw_function=ppw_function)

training_dvpop_fnamei = os.path.join(m_d,"pest.0.dv_pop.csv")
training_opop_fnamei = os.path.join(m_d,"pest.0.obs_pop.csv")

training_dvpopi = pd.read_csv(training_dvpop_fnamei,index_col=0)
training_opopi = pd.read_csv(training_opop_fnamei,index_col=0)
training_dvpop = pd.concat([training_dvpop,training_dvpopi])
training_opop = pd.concat([training_opop,training_opopi])

fig,ax = plt.subplots(1,1,figsize=(6,5))
get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
plt.show()
plt.close(fig)

training_dvpop_fnames.append(training_dvpop_fnamei)
training_opop_fnames.append(training_opop_fnamei)

gpr_t_d = t_d + "_gpr{0}".format(i)
gpr_m_d = gpr_t_d.replace("template","master")
gpst = prep_for_gpr(t_d,training_dvpop_fnames,training_opop_fnames,gpr_t_d)
# we only need these files in memory so we can use the speed of PyPestWorker later....
input_df = pd.read_csv(os.path.join(gpr_t_d,"gpr_input.csv"),index_col=0)
mdf = pd.read_csv(os.path.join(gpr_t_d,"gprmodel_info.csv"),index_col=0)
mdf["model_fname"] = mdf.model_fname.apply(lambda x: os.path.join(gpr_t_d,x))
gpr_sweep_d = sweep_d+"_gpr{0}".format(i)
num_workers = 10
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_sweep_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})

plot_gpr_sweep_results(gpr_sweep_d,training_dvpop)
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:30:06
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_model_2"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
#
#   ---  sanity_check warnings  ---
# ...mou_population_size < 20, this is prob too few
# ...continuing initialization...
# ...loading dv population from csv file retrain_2_dvpop.csv
# ...dv population with 10 members read from 'retrain_2_dvpop.csv'
#
# ...previous generation numbers detected in dv population, fast forwarding generation counter to 8
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 10
# ...running population of size  10
#     running model 10 times
#     starting at 06/06/25 08:30:06
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:30:11 remaining file transfers: 0
#
#    10 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0801 run mgr time (min)
#    1 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         3          0      3.34715     0.573079      2.71292       4.8324
# PAR2                         5          0      2.66225     0.437258        2.076      3.54359
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=8_MEMBER=619_PSO as nearest-to-mean single point
#     with distance of 0.241279 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.444563    0.4472597    -2.012917    -0.425952    -1.951377
#
# ... saved initial dv population to  pest.0.dv_pop.csv
#
#   ---  WARNING: less than 20 active population members...might not be enough  ---
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved observation population of size 1 X 1 to 'pest.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:30:06
# finished at 06/06/25 08:30:11
# took 0.0666667 minutes
# 2025-06-06 08:30:07.605452 : trying to connect to localhost:5544...
# 2025-06-06 08:30:07.861118 : connected to localhost:5544
# using all adjustable parameters as inputs
# input names: ['par1', 'par2']
# 'mou_objectives' not found in ++ options, using all ineq tagged non-zero weighted obs as objectives
# objectives: ['sim']
# constraints: []
# loading input and output files
# ...loaded hosaki_model_master/pest.0.dv_pop.csv hosaki_model_master/pest.0.obs_pop.csv
# ...loaded hosaki_model_master_1/pest.0.dv_pop.csv hosaki_model_master_1/pest.0.obs_pop.csv
# ...loaded hosaki_model_2/pest.0.dv_pop.csv hosaki_model_2/pest.0.obs_pop.csv
# aggregated training dataset shape (30, 3) saved to hosaki_template/pest.pst.aggresults.csv
# Hyperparameter(name='length_scale', value_type='numeric', bounds=array([[1.e-04, 1.e+04]]), n_elements=1, fixed=False)
# training GPR for sim with 30 data points
# WARNING: not applying StandardScalar transformation - user beware!
# sim optimized kernel: Matern(length_scale=7.25, nu=0.5)
# ...plotting fits for sim
# GPR model info saved to hosaki_template_gpr2/gprmodel_info.csv
# noptmax:0, npar_adj:2, nnz_obs:1
# saved gpr pst: pest.pst in gpr_t_d hosaki_template_gpr2
# ./pestpp-mou pest.pst
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/pst/pst_utils.py:922: UserWarning: error processing instruction file hosaki_template_gpr2/gpr_output.csv.ins, trying inschek: output file 'hosaki_template_gpr2/gpr_output.csv' not found
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:30:12
# ...processing command line: ' ./pestpp-mou pest.pst'
# ...using serial run manager
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template_gpr2"
# processing control file pest.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  1
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...less_than inequality defined for observations:  1
# ...running control file parameter values
# ...running population of size  1
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 06/06/25 08:30:12 processing template files with 1 threads...
# 06/06/25 08:30:12 done, took 0 seconds
# 06/06/25 08:30:12 calling forward run command(s)
# 06/06/25 08:30:12 calling forward run command: 'python forward_run.py'
# ...pid: 49977
# ...exit_code: 49977
# ...status: 0
# 06/06/25 08:30:13 forward run command(s) finished, took 0.882 seconds
# 06/06/25 08:30:13 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 06/06/25 08:30:13 done, took 0 seconds
#
#
# -->06/06/25 08:30:13 run complete, took: 0.882 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 0.882 seconds
#
#
#
#
# ...saving results from control file parameter value run to  pest.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        20568.5              0        20568.5        20568.5
#          actual        20568.5              0        20568.5        20568.5
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.06e+04         0  2.06e+04  2.06e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#   ---  control file parameter objective function summary:   ---
# using member BASE as nearest-to-mean single point
#     with distance of 0 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.9116384            0   -0.9116384   -0.9116384   -0.9116384
#
# iteration 0: 0 obs constraints and 0 prior info constraints not satisfied, see rec file for listing
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:30:12
# finished at 06/06/25 08:30:13
# took 0 minutes
# noptmax:-1, npar_adj:2, nnz_obs:1
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:30:13
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep_gpr2"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:30:13
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:14 mn:0     runs(C0    |F0    |T0    ) agents(R0   |W0   |U0   ) 0
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:30:39 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.438 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        26489.8        14357.4         1312.1          79765
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.65e+04  1.44e+04  1.31e+03  7.98e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        26489.8        14357.4         1312.1          79765
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.65e+04  1.44e+04  1.31e+03  7.98e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:30:13
# finished at 06/06/25 08:30:39
# took 0.433333 minutes
# 2025-06-06 08:30:15.402520 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.658048 : connected to localhost:5544
# 2025-06-06 08:30:15.317322 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.573023 : connected to localhost:5544
# 2025-06-06 08:30:15.319063 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.574525 : connected to localhost:5544
# 2025-06-06 08:30:15.334900 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.591044 : connected to localhost:5544
# 2025-06-06 08:30:15.322831 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.578271 : connected to localhost:5544
# 2025-06-06 08:30:15.345947 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.601331 : connected to localhost:5544
# 2025-06-06 08:30:15.343793 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.599196 : connected to localhost:5544
# 2025-06-06 08:30:15.337802 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.593549 : connected to localhost:5544
# 2025-06-06 08:30:15.364513 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.620018 : connected to localhost:5544
# 2025-06-06 08:30:15.383201 : trying to connect to localhost:5544...
# 2025-06-06 08:30:15.638648 : connected to localhost:5544

# %%
gpst.control_data.noptmax = 8
gpst.pestpp_options["mou_population_size"] = 20
gpst.write(os.path.join(gpr_t_d,"pest.pst"))

num_workers = 3
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-mou","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_m_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})



plot_gpr_mou_results(gpr_m_d,gpr_sweep_d)
# Out:
# noptmax:8, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:30:40
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_master_gpr2"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  20
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 20
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:40
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:30:45 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00434 avg run time (min) : 0.0812 run mgr time (min)
#    3 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.12213      1.54413   0.00702338      4.93751
# PAR2                         5          0      1.77721      1.16281    0.0697003      4.51348
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=15 as nearest-to-mean single point
#     with distance of 0.370312 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.6709906    0.5643503    -1.812606    0.1691919   -0.9474384
#
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.0.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:45
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:47 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0298 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.1.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.1.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.1.archive.obs_pop.csv'
# ...resizing current populations to  20
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.75452     0.844359      2.18848            5
# PAR2                         5          0      2.25775      0.93974     0.460033       4.7592
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -1.63239     -76.922  -0.0624922    -1.26566    -2.18145    -31059.8
# PAR2                  -0.480535    -27.0387   -0.245721    -5.44415   -0.390333    -560.016
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.273018    0.3307585    -1.986243    -0.825357    -1.986243
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.602028           0    0.994549     587.823    0.173638           0      1.0388           0
#
# ...number of feasible solutions at the end of generation 1: 2
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:47
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:49 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0296 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.2.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.2.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.61525      0.60194      2.78725      4.61257
# PAR2                         5          0      2.27742     0.604144      1.18311      3.39524
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.139274     3.70951    0.387428     7.74856    -0.59877    -27.3601
# PAR2                 -0.0196699    -0.87122     1.36396     28.6594   -0.723078     -157.18
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.45968    0.2275543    -1.986243    -1.168341    -1.986243
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.186662           0    0.342984           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 2: 40
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:49
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:50 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.3.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.3.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.75005     0.536389      2.95602      4.61257
# PAR2                         5          0      2.25304     0.534039      1.29204      3.39524
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.134797    -3.72858           0           0   -0.168779    -6.05542
# PAR2                  0.0243704     1.07009           0           0   -0.108933    -9.20736
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.553995    0.2223816    -1.986243    -1.301908    -1.986243
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0943154           0    0.133567           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 3: 39
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:50
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:52 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.4.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.4.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.65619      0.43091      3.05887      4.47341
# PAR2                         5          0      2.29948     0.520564      1.48927      3.39524
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0938523      2.5027    0.139162     3.01701   -0.102844    -3.47912
# PAR2                 -0.0464345    -2.06096           0           0   -0.197226    -15.2647
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.628436    0.1987303    -1.986243    -1.361437    -1.986243
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0744409           0   0.0595287           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 39
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:52
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:54 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.5.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.5.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.5682     0.317329      3.05887      4.16672
# PAR2                         5          0      2.32034     0.425563      1.62066      3.20926
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0879942     2.40672    0.306687     6.85578           0           0
# PAR2                 -0.0208563   -0.907001    0.185983     5.47775   -0.131387    -8.82225
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.71813    0.1490251    -1.986243    -1.493846    -1.986243
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0896944           0    0.132409           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 5: 39
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:54
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:56 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.6.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.6.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.55238     0.234367       3.2019      3.94937
# PAR2                         5          0      2.27467     0.337898      1.68814      2.95854
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0158229    0.443443     0.21735     5.21633    -0.14303     -4.6759
# PAR2                  0.0456633     1.96796    0.250719     7.81235  -0.0674825    -4.16389
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.798544    0.1098147    -1.986243    -1.632985    -1.986243
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0804133           0    0.139138           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 6: 39
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:56
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:58 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.7.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.54709     0.197609      3.22073      3.91597
# PAR2                         5          0      2.25427      0.28461      1.86664      2.95854
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 0.00528631    0.148811   0.0333994    0.845688  -0.0188307   -0.588109
# PAR2                  0.0203999    0.896828           0           0   -0.178498    -10.5737
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.845023   0.09030548    -1.986243    -1.711575    -1.986243
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0464788           0   0.0785899           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 7: 40
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:30:58
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:30:59 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.8.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.54516     0.169487      3.28435      3.91597
# PAR2                         5          0      2.23108     0.218974      1.90213      2.71074
#
#
#   ---  generation 8 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 0.00192667    0.054317           0           0  -0.0636246    -1.97547
# PAR2                  0.0231907     1.02875    0.247805      8.3759  -0.0354878    -1.90116
#
#
#   ---  generation 8 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=29_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.881117   0.07111824    -1.986243    -1.781678    -1.986243
#
#
#   ---  generation 8 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0360947           0   0.0701035           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 8: 40
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:30:40
# finished at 06/06/25 08:30:59
# took 0.316667 minutes
# 2025-06-06 08:30:42.312265 : trying to connect to localhost:5544...
# 2025-06-06 08:30:42.567825 : connected to localhost:5544
# 2025-06-06 08:30:42.312026 : trying to connect to localhost:5544...
# 2025-06-06 08:30:42.567833 : connected to localhost:5544
# 2025-06-06 08:30:42.312019 : trying to connect to localhost:5544...
# 2025-06-06 08:30:42.567842 : connected to localhost:5544

# %%
i = 3
gpr_t_d = t_d + "_gpr{0}".format(i-1)
gpr_m_d = gpr_t_d.replace("template","master")
gpr_dvpops = [os.path.join(gpr_m_d,f) for f in os.listdir(gpr_m_d) if len(f.split('.')) == 4 and f.endswith("dv_pop.csv") and "archive" not in f]
gpr_dvpops_itr = [int(f.split(".")[1]) for f in gpr_dvpops]
gpr_dvpops = {itr:pd.read_csv(f,index_col=0) for itr,f in zip(gpr_dvpops_itr,gpr_dvpops)}
# only use the first 10 members of the emulated population to evaluate in the model to make things more interesting
gpr_dvpops[max(gpr_dvpops_itr)].iloc[:10,:].to_csv(os.path.join(t_d,"retrain_{0}_dvpop.csv".format(i)))
pst.pestpp_options["mou_dv_population_file"] = "retrain_{0}_dvpop.csv".format(i)
pst.control_data.noptmax = -1
pst.write(os.path.join(t_d,"pest.pst"))
m_d = "hosaki_model_{0}".format(i)
num_workers = 1
pyemu.os_utils.start_workers(t_d,"pestpp-mou","pest.pst",
                                 num_workers=num_workers,
                                 master_dir=m_d,worker_root='.',
                                 port=port,ppw_function=ppw_function)

training_dvpop_fnamei = os.path.join(m_d,"pest.0.dv_pop.csv")
training_opop_fnamei = os.path.join(m_d,"pest.0.obs_pop.csv")

training_dvpopi = pd.read_csv(training_dvpop_fnamei,index_col=0)
training_opopi = pd.read_csv(training_opop_fnamei,index_col=0)
training_dvpop = pd.concat([training_dvpop,training_dvpopi])
training_opop = pd.concat([training_opop,training_opopi])

fig,ax = plt.subplots(1,1,figsize=(6,5))
get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
plt.show()
plt.close(fig)

training_dvpop_fnames.append(training_dvpop_fnamei)
training_opop_fnames.append(training_opop_fnamei)
gpr_t_d = t_d + "_gpr{0}".format(i)
gpr_m_d = gpr_t_d.replace("template","master")

gpst = prep_for_gpr(t_d,training_dvpop_fnames,training_opop_fnames,gpr_t_d)
# we only need these files in memory so we can use the speed of PyPestWorker later....
input_df = pd.read_csv(os.path.join(gpr_t_d,"gpr_input.csv"),index_col=0)
mdf = pd.read_csv(os.path.join(gpr_t_d,"gprmodel_info.csv"),index_col=0)
mdf["model_fname"] = mdf.model_fname.apply(lambda x: os.path.join(gpr_t_d,x))
gpr_sweep_d = sweep_d+"_gpr{0}".format(i)
num_workers = 10
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_sweep_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})

plot_gpr_sweep_results(gpr_sweep_d,training_dvpop)
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:31:01
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_model_3"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
#
#   ---  sanity_check warnings  ---
# ...mou_population_size < 20, this is prob too few
# ...continuing initialization...
# ...loading dv population from csv file retrain_3_dvpop.csv
# ...dv population with 10 members read from 'retrain_3_dvpop.csv'
#
# ...previous generation numbers detected in dv population, fast forwarding generation counter to 8
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 10
# ...running population of size  10
#     running model 10 times
#     starting at 06/06/25 08:31:01
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:31:06 remaining file transfers: 0
#
#    10 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0838 run mgr time (min)
#    1 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         3          0      3.45909      0.29578      2.88491      3.77559
# PAR2                         5          0      2.18063      0.39186      1.64675       2.8368
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=8_MEMBER=311_PSO as nearest-to-mean single point
#     with distance of 0.163747 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.901436    0.3315991    -2.232979    -1.289699    -2.142413
#
# ... saved initial dv population to  pest.0.dv_pop.csv
#
#   ---  WARNING: less than 20 active population members...might not be enough  ---
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved observation population of size 1 X 1 to 'pest.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:31:01
# finished at 06/06/25 08:31:06
# took 0.0833333 minutes
# 2025-06-06 08:31:02.240576 : trying to connect to localhost:5544...
# 2025-06-06 08:31:02.496149 : connected to localhost:5544
# using all adjustable parameters as inputs
# input names: ['par1', 'par2']
# 'mou_objectives' not found in ++ options, using all ineq tagged non-zero weighted obs as objectives
# objectives: ['sim']
# constraints: []
# loading input and output files
# ...loaded hosaki_model_master/pest.0.dv_pop.csv hosaki_model_master/pest.0.obs_pop.csv
# ...loaded hosaki_model_master_1/pest.0.dv_pop.csv hosaki_model_master_1/pest.0.obs_pop.csv
# ...loaded hosaki_model_2/pest.0.dv_pop.csv hosaki_model_2/pest.0.obs_pop.csv
# ...loaded hosaki_model_3/pest.0.dv_pop.csv hosaki_model_3/pest.0.obs_pop.csv
# aggregated training dataset shape (40, 3) saved to hosaki_template/pest.pst.aggresults.csv
# Hyperparameter(name='length_scale', value_type='numeric', bounds=array([[1.e-04, 1.e+04]]), n_elements=1, fixed=False)
# training GPR for sim with 40 data points
# WARNING: not applying StandardScalar transformation - user beware!
# sim optimized kernel: Matern(length_scale=8.9, nu=0.5)
# ...plotting fits for sim
# GPR model info saved to hosaki_template_gpr3/gprmodel_info.csv
# noptmax:0, npar_adj:2, nnz_obs:1
# saved gpr pst: pest.pst in gpr_t_d hosaki_template_gpr3
# ./pestpp-mou pest.pst
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/pst/pst_utils.py:922: UserWarning: error processing instruction file hosaki_template_gpr3/gpr_output.csv.ins, trying inschek: output file 'hosaki_template_gpr3/gpr_output.csv' not found
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:31:07
# ...processing command line: ' ./pestpp-mou pest.pst'
# ...using serial run manager
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template_gpr3"
# processing control file pest.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  1
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...less_than inequality defined for observations:  1
# ...running control file parameter values
# ...running population of size  1
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 06/06/25 08:31:07 processing template files with 1 threads...
# 06/06/25 08:31:07 done, took 0 seconds
# 06/06/25 08:31:07 calling forward run command(s)
# 06/06/25 08:31:07 calling forward run command: 'python forward_run.py'
# ...pid: 50053
# ...exit_code: 50053
# ...status: 0
# 06/06/25 08:31:08 forward run command(s) finished, took 0.876 seconds
# 06/06/25 08:31:08 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 06/06/25 08:31:08 done, took 0 seconds
#
#
# -->06/06/25 08:31:08 run complete, took: 0.876 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 0.877 seconds
#
#
#
#
# ...saving results from control file parameter value run to  pest.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        20630.7              0        20630.7        20630.7
#          actual        20630.7              0        20630.7        20630.7
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.06e+04         0  2.06e+04  2.06e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#   ---  control file parameter objective function summary:   ---
# using member BASE as nearest-to-mean single point
#     with distance of 0 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.9094731            0   -0.9094731   -0.9094731   -0.9094731
#
# iteration 0: 0 obs constraints and 0 prior info constraints not satisfied, see rec file for listing
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:31:07
# finished at 06/06/25 08:31:08
# took 0 minutes
# noptmax:-1, npar_adj:2, nnz_obs:1
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:31:08
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep_gpr3"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:31:08
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:31:34 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.437 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        24935.8        15517.5        157.411        79826.8
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.49e+04  1.55e+04       157  7.98e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        24935.8        15517.5        157.411        79826.8
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.49e+04  1.55e+04       157  7.98e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:31:08
# finished at 06/06/25 08:31:34
# took 0.433333 minutes
# 2025-06-06 08:31:09.884943 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.140609 : connected to localhost:5544
# 2025-06-06 08:31:09.934054 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.189621 : connected to localhost:5544
# 2025-06-06 08:31:09.934074 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.189633 : connected to localhost:5544
# 2025-06-06 08:31:09.928631 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.184149 : connected to localhost:5544
# 2025-06-06 08:31:09.938109 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.193473 : connected to localhost:5544
# 2025-06-06 08:31:09.975638 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.231020 : connected to localhost:5544
# 2025-06-06 08:31:09.968981 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.223951 : connected to localhost:5544
# 2025-06-06 08:31:09.952140 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.207816 : connected to localhost:5544
# 2025-06-06 08:31:09.970647 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.226005 : connected to localhost:5544
# 2025-06-06 08:31:09.949116 : trying to connect to localhost:5544...
# 2025-06-06 08:31:10.205264 : connected to localhost:5544

# %%
gpst.control_data.noptmax = 8
gpst.pestpp_options["mou_population_size"] = 20
gpst.write(os.path.join(gpr_t_d,"pest.pst"))

num_workers = 3
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-mou","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_m_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})



plot_gpr_mou_results(gpr_m_d,gpr_sweep_d)
# Out:
# noptmax:8, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:31:35
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_master_gpr3"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  20
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 20
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:35
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:31:40 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00431 avg run time (min) : 0.0808 run mgr time (min)
#    3 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      2.12213      1.54413   0.00702338      4.93751
# PAR2                         5          0      1.77721      1.16281    0.0697003      4.51348
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=15 as nearest-to-mean single point
#     with distance of 0.370312 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.7414778    0.6407638    -1.976536    0.1883382   -0.9497751
#
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.0.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:40
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:41 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00422 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.1.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.63683     0.803185       2.5367            5
# PAR2                         5          0      2.18968     0.884078     0.460033      3.69266
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -1.51469    -71.3759  -0.0624922    -1.26566    -2.52968      -36018
# PAR2                  -0.412475    -23.2091    0.820824      18.186   -0.390333    -560.016
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=5 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.438345    0.2684025    -1.976536    -1.040005    -1.976536
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.696868           0     1.22834     652.201           0           0     1.02676           0
#
# ...number of feasible solutions at the end of generation 1: 40
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:41
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:43 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00438 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.2.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.2.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.10499     0.657529       3.0451            5
# PAR2                         5          0      2.00451     0.662576      1.13599      3.44846
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.468158    -12.8727           0           0   -0.508401    -20.0418
# PAR2                   0.185172     8.45655      0.2442     6.61311   -0.675959    -146.937
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=5 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.659719    0.1903614    -1.976536     -1.39171    -1.976536
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.221373           0    0.351705           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 2: 39
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:43
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:45 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00422 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.3.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.3.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.3.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.3.archive.obs_pop.csv'
# ...resizing current populations to  20
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.01304     0.514635       3.0451      4.79423
# PAR2                         5          0      1.89611     0.485496      1.18311      2.97916
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0919431     2.23979    0.205765     4.11531           0           0
# PAR2                   0.108405     5.40805    0.469304     13.6091   -0.047119    -4.14783
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=107_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.793476    0.1766315    -2.167375    -1.513358    -2.167375
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.133757           0    0.121649           0    0.190839           0    0.190839           0
#
# ...number of feasible solutions at the end of generation 3: 2
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:45
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:47 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00422 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.4.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.4.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.9728     0.317375      3.26579      4.43368
# PAR2                         5          0       1.8469     0.428375       1.1883      2.52978
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0402416     1.00277    0.360559     7.52068   -0.220689    -7.24733
# PAR2                  0.0492062     2.59511    0.449372     15.0839 -0.00518843   -0.438541
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=107_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.901771    0.1032441    -2.167375    -1.740316    -2.167375
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.108295           0    0.226958           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 40
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:47
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:49 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.0042 avg run time (min) : 0.0296 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.5.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.5.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.95421     0.228265      3.34386      4.26342
# PAR2                         5          0      1.96188     0.392428      1.31807      2.57577
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0185883     0.46789    0.170253     3.83999  -0.0780674    -2.39046
# PAR2                  -0.114978    -6.22546  -0.0459828    -1.81766   -0.129773    -10.9209
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=107_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.971196   0.08349835    -2.167375     -1.86286    -2.167375
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0694255           0    0.122544           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 5: 39
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:49
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:50 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.6.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.6.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  40
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.6.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.6.archive.obs_pop.csv'
# ...resizing current populations to  20
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.98878     0.183226      3.55266      4.26342
# PAR2                         5          0      1.93981     0.307036      1.42059      2.43704
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0345699   -0.874255           0           0   -0.208799    -6.24424
# PAR2                  0.0220675     1.12481    0.138725     5.38577   -0.102519    -7.77794
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=6_MEMBER=239_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.027036   0.08108969    -2.201547    -1.943427    -2.201547
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0558396           0   0.0805667           0   0.0341719           0   0.0341719           0
#
# ...number of feasible solutions at the end of generation 6: 2
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:50
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:52 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.7.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.7.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.7.archive.obs_pop.csv'
# ...resizing current populations to  20
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.87494     0.171287      3.55266      4.12353
# PAR2                         5          0      1.87518     0.251973      1.48552      2.43704
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.113843     2.85408    0.139896     3.28131           0           0
# PAR2                  0.0646327     3.33191           0           0  -0.0649279    -4.57049
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=7_MEMBER=269_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.097079   0.07301285    -2.229483    -1.976536    -2.229483
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0700433           0   0.0331085           0   0.0279364           0   0.0279364           0
#
# ...number of feasible solutions at the end of generation 7: 2
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 20
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  20
#     running model 20 times
#     starting at 06/06/25 08:31:52
#     3 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:31:54 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0297 run mgr time (min)
#    3 agents connected
#
#
# ...saved decision variable population of size 20 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 20 X 2 to 'pest.8.dv_pop.csv'
# ...saved observation population of size 20 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 20 X 2 to 'pest.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  40
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  20
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.77124     0.146811      3.55266      4.05487
# PAR2                         5          0      1.88777     0.169806      1.61877      2.14955
#
#
#   ---  generation 8 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.103701      2.6762    0.068656     1.66498           0           0
# PAR2                 -0.0125952   -0.671678     0.28749     11.7967   -0.133247    -8.96975
#
#
#   ---  generation 8 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=7_MEMBER=269_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.148347   0.04425503    -2.229483    -2.078641    -2.229483
#
#
#   ---  generation 8 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0512674           0    0.102105           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 8: 40
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:31:35
# finished at 06/06/25 08:31:54
# took 0.316667 minutes
# 2025-06-06 08:31:36.896902 : trying to connect to localhost:5544...
# 2025-06-06 08:31:37.152562 : connected to localhost:5544
# 2025-06-06 08:31:36.896917 : trying to connect to localhost:5544...
# 2025-06-06 08:31:37.152569 : connected to localhost:5544
# 2025-06-06 08:31:36.896892 : trying to connect to localhost:5544...
# 2025-06-06 08:31:37.152576 : connected to localhost:5544

# %% [markdown]
# And one last time...and this time with more emulator-based pestpp-mou generations to polish things off since we no longer want to keep a dispersed population (since we aren't doing any more in-filling and retraining)

# %%
i = 4
gpr_t_d = t_d + "_gpr{0}".format(i-1)
gpr_m_d = gpr_t_d.replace("template","master")
gpr_dvpops = [os.path.join(gpr_m_d,f) for f in os.listdir(gpr_m_d) if len(f.split('.')) == 4 and f.endswith("dv_pop.csv") and "archive" not in f]
gpr_dvpops_itr = [int(f.split(".")[1]) for f in gpr_dvpops]
gpr_dvpops = {itr:pd.read_csv(f,index_col=0) for itr,f in zip(gpr_dvpops_itr,gpr_dvpops)}
# only use the first 10 members of the emulated population to evaluate in the model to make things more interesting
gpr_dvpops[max(gpr_dvpops_itr)].iloc[:10,:].to_csv(os.path.join(t_d,"retrain_{0}_dvpop.csv".format(i)))
pst.pestpp_options["mou_dv_population_file"] = "retrain_{0}_dvpop.csv".format(i)
pst.control_data.noptmax = -1
pst.write(os.path.join(t_d,"pest.pst"))
m_d = "hosaki_model_{0}".format(i)
num_workers = 1
pyemu.os_utils.start_workers(t_d,"pestpp-mou","pest.pst",
                                 num_workers=num_workers,
                                 master_dir=m_d,worker_root='.',
                                 port=port,ppw_function=ppw_function)

training_dvpop_fnamei = os.path.join(m_d,"pest.0.dv_pop.csv")
training_opop_fnamei = os.path.join(m_d,"pest.0.obs_pop.csv")

training_dvpopi = pd.read_csv(training_dvpop_fnamei,index_col=0)
training_opopi = pd.read_csv(training_opop_fnamei,index_col=0)
training_dvpop = pd.concat([training_dvpop,training_dvpopi])
training_opop = pd.concat([training_opop,training_opopi])

fig,ax = plt.subplots(1,1,figsize=(6,5))
get_obj_map(ax,sweep_x,sweep_y,sweep_z)
ax.scatter(training_dvpop.loc[:,pst.par_names[0]],training_dvpop.loc[:,pst.par_names[1]],marker='^',c='w',s=20)
plt.show()
plt.close(fig)

training_dvpop_fnames.append(training_dvpop_fnamei)
training_opop_fnames.append(training_opop_fnamei)
gpr_t_d = t_d + "_gpr{0}".format(i)
gpr_m_d = gpr_t_d.replace("template","master")
gpst = prep_for_gpr(t_d,training_dvpop_fnames,training_opop_fnames,gpr_t_d)
# we only need these files in memory so we can use the speed of PyPestWorker later....
input_df = pd.read_csv(os.path.join(gpr_t_d,"gpr_input.csv"),index_col=0)
mdf = pd.read_csv(os.path.join(gpr_t_d,"gprmodel_info.csv"),index_col=0)
mdf["model_fname"] = mdf.model_fname.apply(lambda x: os.path.join(gpr_t_d,x))
gpr_sweep_d = sweep_d+"_gpr{0}".format(i)
num_workers = 10
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-ies","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_sweep_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})

plot_gpr_sweep_results(gpr_sweep_d,training_dvpop)
# Out:
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:31:55
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_model_4"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
#
#   ---  sanity_check warnings  ---
# ...mou_population_size < 20, this is prob too few
# ...continuing initialization...
# ...loading dv population from csv file retrain_4_dvpop.csv
# ...dv population with 10 members read from 'retrain_4_dvpop.csv'
#
# ...previous generation numbers detected in dv population, fast forwarding generation counter to 8
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 10
# ...running population of size  10
#     running model 10 times
#     starting at 06/06/25 08:31:55
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:32:00 remaining file transfers: 0
#
#    10 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0834 run mgr time (min)
#    1 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         3          0      3.69271     0.183044      3.49525      4.08123
# PAR2                         5          0      1.75176      0.24432      1.25975      2.16771
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=8_MEMBER=317_PSO as nearest-to-mean single point
#     with distance of 0.0942716 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.107429    0.1574811    -2.319105    -1.779897    -2.197816
#
# ... saved initial dv population to  pest.0.dv_pop.csv
#
#   ---  WARNING: less than 20 active population members...might not be enough  ---
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved observation population of size 1 X 1 to 'pest.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:31:55
# finished at 06/06/25 08:32:00
# took 0.0833333 minutes
# 2025-06-06 08:31:56.767637 : trying to connect to localhost:5544...
# 2025-06-06 08:31:57.023310 : connected to localhost:5544
# using all adjustable parameters as inputs
# input names: ['par1', 'par2']
# 'mou_objectives' not found in ++ options, using all ineq tagged non-zero weighted obs as objectives
# objectives: ['sim']
# constraints: []
# loading input and output files
# ...loaded hosaki_model_master/pest.0.dv_pop.csv hosaki_model_master/pest.0.obs_pop.csv
# ...loaded hosaki_model_master_1/pest.0.dv_pop.csv hosaki_model_master_1/pest.0.obs_pop.csv
# ...loaded hosaki_model_2/pest.0.dv_pop.csv hosaki_model_2/pest.0.obs_pop.csv
# ...loaded hosaki_model_3/pest.0.dv_pop.csv hosaki_model_3/pest.0.obs_pop.csv
# ...loaded hosaki_model_4/pest.0.dv_pop.csv hosaki_model_4/pest.0.obs_pop.csv
# aggregated training dataset shape (50, 3) saved to hosaki_template/pest.pst.aggresults.csv
# Hyperparameter(name='length_scale', value_type='numeric', bounds=array([[1.e-04, 1.e+04]]), n_elements=1, fixed=False)
# training GPR for sim with 50 data points
# WARNING: not applying StandardScalar transformation - user beware!
# sim optimized kernel: Matern(length_scale=10.8, nu=0.5)
# ...plotting fits for sim
# GPR model info saved to hosaki_template_gpr4/gprmodel_info.csv
# noptmax:0, npar_adj:2, nnz_obs:1
# saved gpr pst: pest.pst in gpr_t_d hosaki_template_gpr4
# ./pestpp-mou pest.pst
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/pst/pst_utils.py:922: UserWarning: error processing instruction file hosaki_template_gpr4/gpr_output.csv.ins, trying inschek: output file 'hosaki_template_gpr4/gpr_output.csv' not found
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:32:01
# ...processing command line: ' ./pestpp-mou pest.pst'
# ...using serial run manager
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_template_gpr4"
# processing control file pest.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  1
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...less_than inequality defined for observations:  1
# ...running control file parameter values
# ...running population of size  1
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 06/06/25 08:32:01 processing template files with 1 threads...
# 06/06/25 08:32:01 done, took 0 seconds
# 06/06/25 08:32:01 calling forward run command(s)
# 06/06/25 08:32:01 calling forward run command: 'python forward_run.py'
# ...pid: 50137
# ...exit_code: 50137
# ...status: 0
# 06/06/25 08:32:02 forward run command(s) finished, took 0.899 seconds
# 06/06/25 08:32:02 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 06/06/25 08:32:02 done, took 0 seconds
#
#
# -->06/06/25 08:32:02 run complete, took: 0.899 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 0.899 seconds
#
#
#
#
# ...saving results from control file parameter value run to  pest.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        20631.6              0        20631.6        20631.6
#          actual        20631.6              0        20631.6        20631.6
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.06e+04         0  2.06e+04  2.06e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#   ---  control file parameter objective function summary:   ---
# using member BASE as nearest-to-mean single point
#     with distance of 0 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.9094425            0   -0.9094425   -0.9094425   -0.9094425
#
# iteration 0: 0 obs constraints and 0 prior info constraints not satisfied, see rec file for listing
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:32:01
# finished at 06/06/25 08:32:02
# took 0 minutes
# noptmax:-1, npar_adj:2, nnz_obs:1
# noptmax:-1, npar_adj:2, nnz_obs:1
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:32:02
# ...processing command line: ' ./pestpp-ies pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_sweep_gpr4"
# on host: "ABQ-GQXTTQ9TWR.local"
#
# processing control file pest.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...loading par ensemble from csv file sweep_in.csv
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  900
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  pest.weights.csv
# ...saved initial parameter ensemble to  pest.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  pest.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 900
#     running model 900 times
#     starting at 06/06/25 08:32:02
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:03 mn:0     runs(C0    |F0    |T0    ) agents(R0   |W0   |U0   ) 0
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:32:29 remaining file transfers: 0
#
#    900 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.438 run mgr time (min)
#    10 agents connected
#
#
# ...saved initial obs ensemble to pest.0.obs.csv
# ...less_than inequality defined for observations:  1
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        24574.3          15959        6.75427        79862.5
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.46e+04   1.6e+04      6.75  7.99e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 1 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or pest.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#
# ...saved adjusted weight ensemble to  pest.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        24574.3          15959        6.75427        79862.5
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group      count  nconflict      mean       std       min       max   percent       std
# less_than      1          1  2.46e+04   1.6e+04      6.75  7.99e+04       100         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10000
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 06/06/25 08:32:02
# finished at 06/06/25 08:32:29
# took 0.433333 minutes
# 2025-06-06 08:32:04.514748 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.770097 : connected to localhost:5544
# 2025-06-06 08:32:04.500798 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.756186 : connected to localhost:5544
# 2025-06-06 08:32:04.518031 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.773559 : connected to localhost:5544
# 2025-06-06 08:32:04.518101 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.773568 : connected to localhost:5544
# 2025-06-06 08:32:04.504583 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.759941 : connected to localhost:5544
# 2025-06-06 08:32:04.497883 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.753579 : connected to localhost:5544
# 2025-06-06 08:32:04.510348 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.765773 : connected to localhost:5544
# 2025-06-06 08:32:04.523413 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.778830 : connected to localhost:5544
# 2025-06-06 08:32:04.527425 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.782728 : connected to localhost:5544
# 2025-06-06 08:32:04.551288 : trying to connect to localhost:5544...
# 2025-06-06 08:32:04.806696 : connected to localhost:5544

# %%
gpst.control_data.noptmax = 20
gpst.pestpp_options["mou_population_size"] = 40
gpst.write(os.path.join(gpr_t_d,"pest.pst"))

num_workers = 5
pyemu.os_utils.start_workers(gpr_t_d,"pestpp-mou","pest.pst",
                             num_workers=num_workers,
                             master_dir=gpr_m_d,worker_root='.',
                             port=port,ppw_function=pyemu.helpers.gpr_pyworker,
                                 ppw_kwargs={"input_df":input_df,
                                            "mdf":mdf})

plot_gpr_mou_results(gpr_m_d,gpr_sweep_d)
# Out:
# noptmax:20, npar_adj:2, nnz_obs:1
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
#
# version: 5.2.16
# binary compiled on Dec  1 2024 at 18:51:00
#
# started at 06/06/25 08:32:29
# ...processing command line: ' ./pestpp-mou pest.pst /h :5544'
# ...using panther run manager in master mode using port 5544
#
# using control file: "pest.pst"
# in directory: "/Users/kmarkovich/Desktop/pyemu/examples/hosaki_master_gpr4"
# processing control file pest.pst
# Note: 3 unused lines in pest control file, see rec file...
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5544 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5544 (IPv4)
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluting chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                            SIM   minimize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  40
# checking for denormal values in dv population
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...running initial population of size 40
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:29
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:30 mn:0     runs(C0    |F0    |T0    ) agents(R0   |W0   |U0   ) 0
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# /Users/kmarkovich/miniforge3/envs/rpo/lib/python3.11/site-packages/pyemu/__init__.py:29: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'
# 06/06 08:32:35 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00427 avg run time (min) : 0.0883 run mgr time (min)
#    5 agents connected
#
#
# ... saved observation population to  pest.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      1.94967      1.37767   0.00702338      4.93751
# PAR2                         5          0       2.5199      1.41193     0.293313      4.98586
#
#
#   ---  initial population objective function summary:  ---
# using member GEN=0_MEMBER=11 as nearest-to-mean single point
#     with distance of 0.687753 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize   -0.7339871    0.5592672    -2.029375    0.2102923   -0.7404098
#
# ... saved initial dv population to  pest.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to pest.pareto.summary.csv
# initialized archives with 1 nondominated members
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.0.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 1
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:35
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:37 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0341 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.1.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.53445      1.12777      1.22759            5
# PAR2                         5          0      2.22983      1.09714     0.114613       4.6509
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   -1.58478    -81.2844  -0.0624922    -1.26566    -1.22057    -17378.7
# PAR2                   0.290068     11.5111    0.334955     6.71809      0.1787     60.9246
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=0_MEMBER=5 as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.299828    0.3569206    -2.029375   -0.8583297    -2.029375
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.565841           0     1.06862      508.16           0           0     1.28896           0
#
# ...number of feasible solutions at the end of generation 1: 80
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:37
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:39 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.2.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.2.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.2.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.2.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.18376     0.711562      2.77733            5
# PAR2                         5          0      1.92233     0.861118     0.421358       3.7239
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  -0.649307    -18.3708           0           0    -1.54974    -126.242
# PAR2                   0.307503     13.7904    0.927002     19.9316   -0.306745    -267.635
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=2_MEMBER=159_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.64506    0.2510404    -2.305851    -1.262389    -2.305851
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.345233           0    0.404059           0    0.276477           0    0.276477           0
#
# ...number of feasible solutions at the end of generation 2: 2
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:39
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:41 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.3.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.3.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.18423     0.601679      3.12611            5
# PAR2                         5          0       1.9187     0.500871       0.8934      3.09856
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.000466431  -0.0111486           0           0   -0.348779    -12.5581
# PAR2                 0.00362747    0.188702    0.625338     16.7925   -0.472042    -112.029
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=2_MEMBER=159_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -1.84831    0.1893317    -2.305851    -1.604209    -2.305851
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                      0.20325           0     0.34182           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 3: 80
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:41
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:43 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.4.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.4.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.20228     0.433732      3.33242      4.92354
# PAR2                         5          0      1.87884     0.515422       1.0612      2.92323
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0180595    -0.43161   0.0764626     1.52925   -0.206311    -6.59961
# PAR2                  0.0398631     2.07761    0.175331     5.65846   -0.167802    -18.7824
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=2_MEMBER=159_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -1.929161    0.1668622    -2.305851    -1.702813    -2.305851
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0808508           0   0.0986039           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 79
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:43
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:45 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.5.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.5.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.5.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.5.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.08817     0.373674      3.48606       4.7169
# PAR2                         5          0      1.89934     0.388844       1.2074      2.70464
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.114113     2.71549    0.206633     4.19685   -0.153641     -4.6105
# PAR2                 -0.0205017    -1.09119    0.218596     7.47788   -0.146199    -13.7767
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=5_MEMBER=403_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.058458    0.1514283    -2.321012    -1.860193    -2.321012
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                     0.129297           0     0.15738           0   0.0151607           0   0.0151607           0
#
# ...number of feasible solutions at the end of generation 5: 2
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:45
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:47 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.6.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.6.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.94632     0.300825      3.48606      4.51348
# PAR2                         5          0      2.05736     0.298783      1.41102      2.56265
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                   0.141849     3.46974     0.20342     4.31258           0           0
# PAR2                   -0.15802     -8.3197    0.141986     5.24973    -0.20362    -16.8643
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=5_MEMBER=403_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.139411     0.102846    -2.321012    -1.994554    -2.321012
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0809529           0     0.13436           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 6: 80
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:47
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:49 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.7.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.9138     0.221733      3.56352      4.40341
# PAR2                         5          0      2.03148     0.237226      1.55154      2.47492
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                  0.0325203    0.824065    0.110075      2.4388  -0.0774573    -2.22191
# PAR2                  0.0258857      1.2582    0.087728     3.42333   -0.140517    -9.95856
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=5_MEMBER=403_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -2.20522   0.07034359    -2.321012     -2.08203    -2.321012
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0658095           0   0.0874759           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 7: 80
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:49
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:51 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.8.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.9371      0.15646         3.69      4.23124
# PAR2                         5          0      2.00447     0.179789      1.70172      2.33273
#
#
#   ---  generation 8 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0232984   -0.595289    0.172168     3.90988   -0.126478    -3.54924
# PAR2                  0.0270026     1.32921     0.14219     5.74524   -0.150186     -9.6798
#
#
#   ---  generation 8 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=5_MEMBER=403_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.260171   0.04093107    -2.321012    -2.193343    -2.321012
#
#
#   ---  generation 8 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0549508           0    0.111314           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 8: 80
#
#   ---  starting generation  9  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:51
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:53 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.9.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.9.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.9.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.9.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 9 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.95241     0.122706      3.74902      4.18357
# PAR2                         5          0      2.01949     0.135539      1.70172      2.24223
#
#
#   ---  generation 9 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0153059    -0.38876   0.0476722     1.12667  -0.0590255    -1.59961
# PAR2                 -0.0150182   -0.749234   0.0905015     3.87963           0           0
#
#
#   ---  generation 9 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=9_MEMBER=717_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.287288   0.02485663    -2.321184    -2.241354    -2.321184
#
#
#   ---  generation 9 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0271166           0   0.0480108           0 0.000172327           0 0.000172327           0
#
# ...number of feasible solutions at the end of generation 9: 2
#
#   ---  starting generation  10  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:53
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:55 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.10.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.10.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.10.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.10.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 10 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.98594    0.0878031       3.8036      4.13112
# PAR2                         5          0      2.00385     0.100373       1.7108      2.20928
#
#
#   ---  generation 10 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0335292   -0.848322   0.0524516     1.25375  -0.0545727    -1.45565
# PAR2                  0.0156423    0.774567   0.0329499     1.46952 -0.00907734    -0.53342
#
#
#   ---  generation 10 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=10_MEMBER=793_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.305606   0.01283953    -2.321275    -2.279679    -2.321275
#
#
#   ---  generation 10 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                    0.0183184           0   0.0383253           0 9.07489e-05           0 9.07489e-05           0
#
# ...number of feasible solutions at the end of generation 10: 2
#
#   ---  starting generation  11  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:55
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:57 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.11.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.11.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 11 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.98121    0.0703884      3.84817      4.11958
# PAR2                         5          0      2.00918    0.0692946      1.85402      2.15076
#
#
#   ---  generation 11 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 0.00472165    0.118458   0.0115339    0.279195  -0.0445744     -1.1719
# PAR2                -0.00533392   -0.266184   0.0585247     2.64904   -0.143223    -8.37169
#
#
#   ---  generation 11 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=10_MEMBER=793_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.312377  0.007675379    -2.321275    -2.295497    -2.321275
#
#
#   ---  generation 11 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                   0.00677035           0   0.0158178           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 11: 80
#
#   ---  starting generation  12  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:57
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:32:59 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00422 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.12.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.12.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.12.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.12.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 12 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0       3.9817    0.0553387        3.874      4.09469
# PAR2                         5          0      2.01305    0.0661595      1.85402      2.15076
#
#
#   ---  generation 12 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.000485825  -0.0122029   0.0248963     0.60434  -0.0258288   -0.671196
# PAR2                -0.00386339   -0.192287           0           0           0           0
#
#
#   ---  generation 12 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=12_MEMBER=957_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -2.31586  0.004859489    -2.322006    -2.305164    -2.322006
#
#
#   ---  generation 12 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                   0.00348388           0  0.00966672           0 0.000730912           0 0.000730912           0
#
# ...number of feasible solutions at the end of generation 12: 2
#
#   ---  starting generation  13  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:32:59
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:01 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.13.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.13.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.13.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.13.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 13 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.99457     0.044854      3.90075      4.07119
# PAR2                         5          0      2.01429     0.059661      1.88767      2.15076
#
#
#   ---  generation 13 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 -0.0128702   -0.323235    0.023502    0.573962  -0.0267546   -0.690619
# PAR2                -0.00124314  -0.0617539           0           0  -0.0336423    -1.81456
#
#
#   ---  generation 13 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=13_MEMBER=1069_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.317935  0.003066885    -2.322798    -2.312338    -2.322798
#
#
#   ---  generation 13 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                   0.00207467           0  0.00717429           0 0.000791661           0 0.000791661           0
#
# ...number of feasible solutions at the end of generation 13: 2
#
#   ---  starting generation  14  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:01
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:03 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.14.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.14.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.14.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.14.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 14 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      3.99873    0.0392211      3.92673       4.0723
# PAR2                         5          0      2.02167    0.0559915      1.91712      2.15076
#
#
#   ---  generation 14 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.00416377   -0.104236 -0.00111142  -0.0272996  -0.0259754   -0.665907
# ...
# using member GEN=15_MEMBER=1205_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -2.32133  0.001232731    -2.323131    -2.319158    -2.323131
#
#
#   ---  generation 15 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                   0.00152028           0  0.00323394           0 4.45107e-06           0 4.45107e-06           0
#
# ...number of feasible solutions at the end of generation 15: 2
#
#   ---  starting generation  16  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:05
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:07 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.16.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.16.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 16 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.00425    0.0220115      3.95884      4.04591
# PAR2                         5          0      2.05397    0.0276216      1.98132      2.09667
#
#
#   ---  generation 16 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 0.00146858   0.0366622   0.0263909     0.64806  -0.0113742   -0.288139
# PAR2                 -0.0137422   -0.673561   0.0425875     1.99076  -0.0300987    -1.54255
#
#
#   ---  generation 16 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=15_MEMBER=1205_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.322317 0.0006561037    -2.323131    -2.321012    -2.323131
#
#
#   ---  generation 16 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                  0.000986672           0  0.00185372           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 16: 80
#
#   ---  starting generation  17  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:07
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:09 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00421 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.17.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.17.obs_pop.csv'
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  80
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 17 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.00802     0.016513      3.97427       4.0371
# PAR2                         5          0      2.05988    0.0196223       2.0153      2.09667
#
#
#   ---  generation 17 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.00377371  -0.0942428  0.00880989    0.217748  -0.0154379   -0.389961
# PAR2                -0.00591228   -0.287847           0           0  -0.0339798      -1.715
#
#
#   ---  generation 17 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=15_MEMBER=1205_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.322672 0.0003439922    -2.323131    -2.322023    -2.323131
#
#
#   ---  generation 17 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                  0.000355241           0  0.00101074           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 17: 79
#
#   ---  starting generation  18  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:09
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:12 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00424 avg run time (min) : 0.0339 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.18.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.18.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# ...wrote pareto summary to pest.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...saved decision variable population of size 1 X 2 to 'pest.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'pest.18.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'pest.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 1 X 2 to 'pest.18.archive.obs_pop.csv'
# ...resizing current populations to  40
#
#   ---  generation 18 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.01159    0.0104586      3.99056      4.03321
# PAR2                         5          0      2.06195    0.0164177      2.03592      2.10081
#
#
#   ---  generation 18 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.00356964  -0.0890623  0.00388119   0.0961381  -0.0162835   -0.409722
# PAR2                -0.00207377   -0.100674 -0.00414011   -0.197461  -0.0206221    -1.02327
#
#
#   ---  generation 18 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=18_MEMBER=1467_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.322916    0.0001708    -2.323151     -2.32259    -2.323151
#
#
#   ---  generation 18 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                   0.00024362           0 0.000567732           0 1.93746e-05           0 1.93746e-05           0
#
# ...number of feasible solutions at the end of generation 18: 2
#
#   ---  starting generation  19  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:12
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:14 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00425 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.19.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.19.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 19 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.01013   0.00873116      3.99056      4.02869
# PAR2                         5          0      2.05817    0.0138593      2.03303      2.08605
#
#
#   ---  generation 19 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                 0.00146242   0.0364548  0.00452906    0.112294           0           0
# PAR2                  0.0037771    0.183181   0.0147607    0.702618  0.00289617    0.142253
#
#
#   ---  generation 19 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=18_MEMBER=1467_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize     -2.32299 0.0001071024    -2.323151     -2.32278    -2.323151
#
#
#   ---  generation 19 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                  7.46047e-05           0 0.000189402           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 19: 80
#
#   ---  starting generation  20  ---
# ...generating PSO population of size 40
# WARNING: pso gbest solution max crowding distance == 0.0, 1 nondom solutions being used
# ...running population of size  40
#     running model 40 times
#     starting at 06/06/25 08:33:14
#     5 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 06/06 08:33:16 remaining file transfers: 0
#
#    40 runs complete :  0 runs failed
#    0.00423 avg run time (min) : 0.0338 run mgr time (min)
#    5 agents connected
#
#
# ...saved decision variable population of size 40 X 2 to 'pest.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 2 to 'pest.20.dv_pop.csv'
# ...saved observation population of size 40 X 2 to 'pest.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 2 to 'pest.20.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  80
# ...wrote pareto summary to pest.pareto.summary.csv
# updating archive
# all nondominated members in already in archive
# ...resizing current populations to  40
#
#   ---  generation 20 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# PAR1                         5          0      4.01039   0.00712459       3.9937      4.02431
# PAR2                         5          0       2.0608    0.0121277      2.03592      2.08605
#
#
#   ---  generation 20 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# PAR1                -0.000257274  -0.0064156  0.00437425    0.108578 -0.00313804  -0.0786365
# PAR2                -0.00262423   -0.127503           0           0 -0.00289617   -0.142456
#
#
#   ---  generation 20 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=18_MEMBER=1467_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# SIM                   minimize    -2.323043 7.002868e-05    -2.323151    -2.322933    -2.323151
#
#
#   ---  generation 20 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# SIM                  5.24984e-05           0 0.000153479           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 20: 80
#
#
# pestpp-mou analysis complete...
# started at 06/06/25 08:32:29
# finished at 06/06/25 08:33:16
# took 0.766667 minutes
# 2025-06-06 08:32:31.707277 : trying to connect to localhost:5544...
# 2025-06-06 08:32:31.962700 : connected to localhost:5544
# 2025-06-06 08:32:31.705810 : trying to connect to localhost:5544...
# 2025-06-06 08:32:31.961326 : connected to localhost:5544
# 2025-06-06 08:32:31.705823 : trying to connect to localhost:5544...
# 2025-06-06 08:32:31.958661 : connected to localhost:5544
# 2025-06-06 08:32:31.697052 : trying to connect to localhost:5544...
# 2025-06-06 08:32:31.952761 : connected to localhost:5544
# 2025-06-06 08:32:31.705957 : trying to connect to localhost:5544...
# 2025-06-06 08:32:31.961410 : connected to localhost:5544

# %% [markdown]
# There you have it - after evaluating only a few populations with the complex process-based model (here that was only the hosaki function), we can effectively optimize a function with the otherwise every expensive global solvers in pestpp-mou.  In general, this approach can reduce the computational demand of mou by 10X to 100X, which is pretty amazing. In this simple and naive demo, we've only run the true "complex" model at the points listed here:

# %%
training_dvpop
# Out:
#                           par1      par2
# real_name
# gen=0_member=0        0.438363  3.552070
# gen=0_member=1        0.004214  1.950710
# gen=0_member=2        0.775812  1.888000
# gen=0_member=3        1.526810  0.074558
# gen=0_member=4        0.390467  4.585150
# gen=0_member=5        2.349580  2.188480
# gen=0_member=6        2.408870  0.022861
# gen=0_member=7        2.081520  0.184029
# gen=0_member=8        0.873526  2.021350
# gen=0_member=9        2.962500  2.956020
# gen=8_member=601_pso  2.864980  2.974940
# gen=8_member=603_pso  3.335080  2.545990
# gen=8_member=605_pso  3.327990  2.819720
# gen=8_member=607_pso  4.492210  3.978880
# gen=8_member=609_pso  3.023480  2.809310
# gen=8_member=611_pso  3.059070  2.817850
# gen=8_member=613_pso  3.198710  2.795530
# gen=8_member=615_pso  2.949060  2.868800
# gen=8_member=617_pso  2.721110  2.981100
# gen=8_member=619_pso  2.235940  3.092050
# gen=8_member=601_pso  2.712920  2.541080
# gen=8_member=603_pso  2.859280  2.662070
# gen=8_member=605_pso  2.997680  2.904780
# gen=8_member=607_pso  3.472390  2.076000
# gen=8_member=609_pso  3.003320  2.542010
# gen=8_member=611_pso  4.832400  3.543590
# gen=8_member=613_pso  3.370240  2.357480
# gen=8_member=615_pso  3.564100  3.224820
# gen=8_member=617_pso  3.071010  2.120000
# gen=8_member=619_pso  3.588150  2.650680
# gen=8_member=301_pso  3.222770  2.836800
# gen=8_member=303_pso  3.766700  1.646750
# gen=8_member=305_pso  3.734530  1.842920
# gen=8_member=307_pso  3.197880  2.455360
# gen=8_member=309_pso  3.775590  1.704510
# gen=8_member=311_pso  3.610510  2.118310
# gen=8_member=313_pso  3.253280  2.468100
# gen=8_member=315_pso  3.744820  1.798780
# gen=8_member=317_pso  3.399880  2.408490
# gen=8_member=319_pso  2.884910  2.526300
# gen=8_member=301_pso  3.958310  1.712890
# gen=8_member=303_pso  3.597150  1.961160
# gen=8_member=305_pso  3.495250  1.702630
# gen=8_member=307_pso  4.081230  2.167710
# gen=8_member=309_pso  3.599650  1.259750
# gen=8_member=311_pso  3.511560  1.749570
# gen=8_member=313_pso  3.598450  1.518650
# gen=8_member=315_pso  3.734550  2.024860
# gen=8_member=317_pso  3.755280  1.681240
# gen=8_member=319_pso  3.595700  1.739100

# %%
print("The complex model has only been run {0} times!!!".format(training_dvpop.shape[0]))
# Out:
# The complex model has only been run 50 times!!!
